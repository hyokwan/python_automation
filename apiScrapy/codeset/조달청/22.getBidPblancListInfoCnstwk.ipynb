# %% [markdown]
# # 1. 필요 라이브러리 선언

# %%
from datetime import datetime, timedelta
import pandas as pd
import requests
from lxml import html
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote
import os
import time
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %% [markdown]
# # 2. 함수 선언

# %%
### 함수정의: 시작일시(datetime 타입)를 입력 시 한달 후의 시작 및 종료일시를 반환하는 함수
### 파마리터정의:
###   - inDf: 시작일시 (예: datetime(2020,1,1))
def getAfterMonthDate(inDt):
    startYear = inDt.year
    startMonth = inDt.month
    endYear = inDt.year
    endMonth = inDt.month + 1
    if startMonth == 12:
        startYear += 1
        startMonth = 1
        endYear = startYear
        endMonth = startMonth + 1
    elif startMonth == 11:
        startMonth += 1
        endYear = startYear + 1
        endMonth = 1
    else:
        startMonth += 1
        endMonth = startMonth + 1
    outBgnDt = datetime(startYear, startMonth, inDt.day)
    outEndDt = datetime(endYear, endMonth, inDt.day) - timedelta(seconds=1)
    return outBgnDt, outEndDt

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
### 파마리터정의: 
###   - inurl: 메타정보의 "URL"컬럼값 (예: https://www.calspia.go.kr/io/openapi/cm/selectIoCmConstructionList.do )
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
###   - inParam: 메타정보의 "기본키 정보" (예: {'ServiceKey': 't1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g==','type':'json',...}")
###   - inPageYn: 메타정보의 "페이지 정보" (예: 페이지 파라미터 존재 시 1 값")
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
def scrapy(inUrl, inSiteName, inDataName, inServiceName, inParam, inPageYn):
    emptyPd = pd.DataFrame()
    i=1
    while True:
        jsondata = pd.DataFrame()
        print("{} page scraping start".format(i))

        if(inPageYn==1):
            inParam["pageNo"] = i
        queryParams = '?' + urlencode(inParam)

        response = requests.get(inUrl+queryParams)
        
        time.sleep(0.1)
        
        print(inUrl+queryParams)
        response.encoding=STDENCODING
        
        if response.json()["response"]["body"]["totalCount"] == 0:
            print("데이터 없음")
            break

        try:
            jsondata = response.json()["response"]["body"]["items"]
        except Exception as e:
            if e.args[0] == 'Expecting value: line 1 column 1 (char 0)':
                xmlobj = BeautifulSoup(response.text,"lxml-xml")
                errorCode = xmlobj.find("returnReasonCode").text
                raise Exception(errorCode)

        if( jsondata == []):
            print("{} page is empty".format(i))
            break

        rowData = pd.DataFrame(jsondata)
#        print(rowData)
        emptyPd = emptyPd.append(rowData)

        if(inPageYn == 0):
            print("{} no pageNo".format(inPageYn))
            break
        i = i+1

    print("dataframe {} completed".format(inDataName))
    return emptyPd

# %%
### 함수정의: 데이터프레임을 Append 모드로 OUTPUT PATH에 저장하는 함수
### 파마리터정의:  (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
###   - inDf: 저장할 대상 데이터프레임
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
def savedata(inDf, inSiteName, inDataName, inServiceName):
    # DATA SAVE TO THE OUTPUT PATH FOLDER
    outDir = os.path.join(OUTPUTPATH,inSiteName,inDataName)
    outFile = os.path.join( outDir, inServiceName) + ".csv"
    createFolder(outDir)
    inDf.to_csv(outFile, index=False, encoding="ms949", mode="a")
    print("{} save compled".format(inDataName) )

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수 (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
### 파마리터정의: 
###   - directory: outputpath 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
# def thread_crawl(paramList, inUrl, inSiteName, inDataName, inServiceName, inPageYn, fuction):
#     per_thread_num = 8
#     thread_list = []
#     result_list = []
#     with ThreadPoolExecutor(max_workers=per_thread_num) as exe:
#         for param in paramList:
#             fs = exe.submit(fuction,URL,SITENAME,DATANAME,SERVICENAME,param,PAGEYN)
#             thread_list.append(fs)
#         for execution in concurrent.futures.as_completed(thread_list):
#             df = execution.result()
#             result_list.append(df)
#     return result_list

# %% [markdown]
# # 3. 필요 변수 선언

# %% [markdown]
# ### 가) 메타데이터 업로드

# %%
metadata = pd.read_excel("../../input/datalake_meta22.xlsx", sheet_name="2. 조달청-조달정보개방포털", dtype={"순서":str, "비고":str})

# %% [markdown]
# ### 나) output 폴더 생성 변수

# %%
SITENAME = "조달청"

# %%
DATANAME= "입찰공고목록 정보에 대한 공사조회"

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

# %%
SERVICENAME = targetData["서비스키"].values[0]

# %% [markdown]
# ### 다) 기본키 설정 (서비스별 변경 요)

# %% [markdown]
# #### 1) API KEY

# %%
initServiceKey = "t1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g=="

# %%
ServiceKeyLst = ["hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay+8Hgy660JdC9mVQCFhRKupVGwaw==",\
                 "Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x+MPLarA==",\
                "h2pHFUSHMnsx/wJfhd+fyC4L0X+g16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8/G+twwMfA9m8Q==",\
                "gDMXFxO2+zC7ZuEFiUXl+aWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG/0rQ/g/k2elw==",\
                "6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA=="]

# %% [markdown]
# #### 2) 조회 구분

# %%
inqryDiv = 1

# %% [markdown]
# #### 3) 등록일시 기준 조회 시작일자 및 종료일자

# %%
startYear, startMonth, startDay = 2012, 1, 1
bgnDt = datetime(startYear, startMonth, startDay)
endDt = datetime(startYear, startMonth + 1, startDay) - timedelta(seconds=1)

# %% [markdown]
# #### 4) 조회 rows 수

# %%
numOfRows = 999

# %% [markdown]
# #### 5) 기본키 딕셔너리 생성

# %%
BASEPARAM_KEY = targetData.기본키.values[0].split(",")

# %%
BASEPARAM_KEY
# Out:
# ['numOfRows', 'ServiceKey', 'inqryDiv', 'inqryBgnDt', 'inqryEndDt']

# %%
BASEPARAM_Lst = []

# %%
nowDt = datetime.now().strftime("%Y%m%d%H%M")

# %%
while True:
    inqryBgnDt = bgnDt.strftime("%Y%m%d%H%M")
    inqryEndDt = endDt.strftime("%Y%m%d%H%M")
    if inqryBgnDt > nowDt:
        break
    BASEPARAM = {}
    BASEPARAM_VAL = [numOfRows, initServiceKey, inqryDiv, inqryBgnDt, inqryEndDt]
    for i in range(len(BASEPARAM_VAL)):
        BASEPARAM[BASEPARAM_KEY[i]] = BASEPARAM_VAL[i]
        BASEPARAM["type"] = "json"
    BASEPARAM_Lst.append(BASEPARAM)    
    bgnDt, endDt = getAfterMonthDate(bgnDt)

# %% [markdown]
# ### 5) 함수 파라미터 설정

# %%
URL = targetData["URL"].values[0]

# %%
PAGEYN=1

# %%
STDENCODING='utf-8'

# %% [markdown]
# ### 6) OUTPUT 기본경로 설정

# %%
OUTPUTPATH="../../output"

# %% [markdown]
# # 4. 데이터 수집

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

if os.path.isfile(filePath):
    os.remove(filePath)

# %%
breakPoint = 0

# %% [markdown]
# ## 가) 초기 인증키를 통한 수집

# %%
flag = False

# %%
starttime = time.time()
print("수집시작 : ", time.strftime('%c', time.localtime(time.time())))
for i in range(breakPoint, len(BASEPARAM_Lst)):
    try:
        resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
        print(resultDf)
        savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
    except Exception as e:
        print(e)
        breakPoint = i
        if e.args[0] == "22":
            print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
        break
    if i == len(BASEPARAM_Lst) - 1:
        flag = True
# Out:
# 수집시작 :  Thu Mar 31 20:08:11 2022
# 1 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202111010000&inqryEndDt=202111302359&pageNo=19
# 19 page is empty
# dataframe 입찰공고목록 정보에 대한 공사조회 completed
#        bidNtceNo bidNtceOrd reNtceYn            rgstTyNm ntceKindNm intrbidYn  \
# 0    20210821355         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# 1        2102911         04        N            연계기관 공고건         변경         Y
# 2        2102911         05        N            연계기관 공고건         변경         Y
# 3        2102911         06        N            연계기관 공고건         변경         Y
# 4        2103503         02        N            연계기관 공고건         취소         Y
# ..           ...        ...      ...                 ...        ...       ...
# 382      MCX0200          1                     연계기관 공고건                    N
# 383      MDG0133          1                     연계기관 공고건                    N
# 384      SEE0057          1                     연계기관 공고건                    N
# 385      MDG0139          1                     연계기관 공고건                    N
# 386      LCN0052          1                     연계기관 공고건                    N
#
#                bidNtceDt         refNo                         bidNtceNm  \
# 0    2021-11-29 14:20:01  석포농장 2021-01     축산분야 ICT 융복합확산사업 사료배합기 시설설치공사
# 1    2021-11-02 16:35:01                  00사단 000연대본부 및 0·0대대 이전사업 건축공사
# 2    2021-11-15 17:05:01                  00사단 000연대본부 및 0·0대대 이전사업 건축공사
# 3    2021-11-22 10:35:01                  00사단 000연대본부 및 0·0대대 이전사업 건축공사
# 4    2021-11-16 15:50:02                성남복정1 A-2BL 및 A-3BL 아파트 건설공사 2공구
# ..                   ...           ...                               ...
# 382                                                   00지역 시스템에어컨 중앙제어공사
# 383                                                수도병원 승강기 교체 전기공사 등 2건
# 384                                                    21-J-유휴시설 철거 전기공사
# 385                                                   의무사 아파트 분리수거장 개선공사
# 386                                                육사교 북카페 인테리어 공사(리모델링)
#
#     ntceInsttCd  ... d2bMngNgttnStleNm d2bMngDmndYear d2bMngCnstwkNo  \
# 0       Z043907  ...
# 1       B552555  ...
# 2       B552555  ...
# 3       B552555  ...
# 4       B552555  ...
# ..          ...  ...               ...            ...            ...
# 382              ...              전자협상                    2021-23653
# 383              ...                                      2021-23566
# 384              ...              전자협상                    2021-23604
# 385              ...              전자협상                    2021-23641
# 386              ...              전자협상                    2021-23606
#
#     cnstrtsiteRgnNm rgnDutyJntcontrctYn chgNtceRsn rbidOpengDt ciblAplYn  \
# 0          충청북도 충주시                   N     재공고 예정                     N
# 1                                                                      N
# 2                                                                      N
# 3                                                                      N
# 4                                                                      N
# ..              ...                 ...        ...         ...       ...
# 382
# 383
# 384
# 385
# 386
#
#     mtltyAdvcPsblYn mtltyAdvcPsblYnCnstwkNm
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ..              ...                     ...
# 382
# 383
# 384
# 385
# 386
#
# [17370 rows x 155 columns]
# 입찰공고목록 정보에 대한 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202112010000&inqryEndDt=202112312359&pageNo=21
# 21 page is empty
# dataframe 입찰공고목록 정보에 대한 공사조회 completed
#        bidNtceNo bidNtceOrd reNtceYn            rgstTyNm ntceKindNm intrbidYn  \
# 0    20210727440         02        N  조달청 또는 나라장터 자체 공고건         취소         N
# 1    B3202103667         02        N            연계기관 공고건         변경         N
# 2    B3202103667         03        N            연계기관 공고건         변경         N
# 3    B3202103667         04        N            연계기관 공고건         변경         N
# 4    20211101570         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# ..           ...        ...      ...                 ...        ...       ...
# 526      LHK0381          1                     연계기관 공고건                    N
# 527      LHM0145          1                     연계기관 공고건                    N
# 528      SCH0064          1                     연계기관 공고건                    N
# 529      LCK0252          1                     연계기관 공고건                    N
# 530      LNQ0313          1                     연계기관 공고건                    N
#
#                bidNtceDt              refNo                         bidNtceNm  \
# 0    2021-12-09 14:31:16            7000690  서울대학교 자동화시스템공동연구소 옥상 단열 복합 방수 공사
# 1    2021-09-30 14:00:00     B3202103667-02        고성군 지방상수도 현내정수장 현대화사업 시설공사
# 2    2021-09-30 14:00:00     B3202103667-03        고성군 지방상수도 현내정수장 현대화사업 시설공사
# 3    2021-09-30 14:00:00     B3202103667-04        고성군 지방상수도 현내정수장 현대화사업 시설공사
# 4    2021-12-20 16:18:35  완산중학교 공고 제2021-29             완산학원 운동장 조성 연결통로 설치공사
# ..                   ...                ...                               ...
# 526                                                          교량대대 개편 시설공사(소방)
# 527                                                     50연대 병영생활관 지정폐기물 철거공사
# 528                                                  21-해-경 0000대대 본관 증축 통신공사
# 529                                                   21-257 00부대 울타리 변경 통신공사
# 530                                                           02포병대대 방호문 보수공사
#
#     ntceInsttCd  ... d2bMngNgttnStleNm d2bMngDmndYear d2bMngCnstwkNo  \
# 0       7000690  ...
# 1       B500001  ...
# 2       B500001  ...
# 3       B500001  ...
# 4       8330049  ...
# ..          ...  ...               ...            ...            ...
# 526              ...              전자협상                    2021-27689
# 527              ...              전자협상                    2021-27736
# 528              ...              전자협상                    2021-27800
# 529              ...              전자협상                    2021-27807
# 530              ...                                      2021-27901
#
#     cnstrtsiteRgnNm rgnDutyJntcontrctYn  \
# 0         서울특별시 관악구                   N
# 1
# 2
# 3
# 4      전라북도 전주시 완산구                   N
# ..              ...                 ...
# 526
# 527
# 528
# 529
# 530
#
#                                      chgNtceRsn rbidOpengDt ciblAplYn  \
# 0    - 방수공사 면적 산출 오류\r\n- 물가인상률 미반영에 따른 예정가격 변경                     Y
# 1                                                                   N
# 2                                                                   N
# 3                                                                   N
# 4                           물가 상승으로 인한 공사진행이 불가                     Y
# ..                                          ...         ...       ...
# 526
# 527
# 528
# 529
# 530
#
#     mtltyAdvcPsblYn mtltyAdvcPsblYnCnstwkNm
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ..              ...                     ...
# 526
# 527
# 528
# 529
# 530
#
# [19512 rows x 155 columns]
# 입찰공고목록 정보에 대한 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202201010000&inqryEndDt=202201312359&pageNo=10
# 10 page is empty
# dataframe 입찰공고목록 정보에 대한 공사조회 completed
#        bidNtceNo bidNtceOrd reNtceYn            rgstTyNm ntceKindNm intrbidYn  \
# 0    20211127880         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# 1    20211137090         01        N  조달청 또는 나라장터 자체 공고건         변경         Y
# 2      202101359         01        N            연계기관 공고건         변경         Y
# 3        2104511         01        N            연계기관 공고건         변경         Y
# 4    20211220746         01        N  조달청 또는 나라장터 자체 공고건         변경         N
# ..           ...        ...      ...                 ...        ...       ...
# 821      SCP0002          1                     연계기관 공고건                    N
# 822      LNF0191          1                     연계기관 공고건                    N
# 823      SFM0002          1                     연계기관 공고건                    N
# 824      SFM0004          1                     연계기관 공고건                    N
# 825      SCK0001          1                     연계기관 공고건                    N
#
#                bidNtceDt                 refNo  \
# 0    2022-01-07 11:29:09  경상여자중학교 공고 제2021-31호
# 1    2022-01-04 18:02:56             210369600
# 2    2022-01-28 00:00:00                     0
# 3    2022-01-06 11:35:01
# 4    2022-01-05 16:30:16      사업운영팀(공사)제21-03호
# ..                   ...                   ...
# 821
# 822
# 823
# 824
# 825
#
#                                           bidNtceNm ntceInsttCd  ...  \
# 0                  경상여자중학교 외벽 보수 공사 소액수의 견적제출 안내 공고     7260056  ...
# 1                                   경주 양남-감포 국도건설공사     1230000  ...
# 2    [긴급][국제입찰][정정공고]행복도시 연결도로(경부고속도로 회덕IC 신설) 건설공사     B500004  ...
# 3                      인천부평 행복주택 및 도시재생뉴딜 혁신센터 건설공사     B552555  ...
# 4                                    법인사무처 사무실 개편공사     B552385  ...
# ..                                              ...         ...  ...
# 821                        22-0함대 00전대 이전 통신공사 설계용역              ...
# 822                           (임시-2) 임시숙영시설 설치 전기공사              ...
# 823                                22-S-01 대규모 보수공사              ...
# 824                                22-S-03 대규모 보수공사              ...
# 825                             22-1 교육사 전반 건축 보수공사              ...
#
#     d2bMngNgttnStleNm d2bMngDmndYear d2bMngCnstwkNo cnstrtsiteRgnNm  \
# 0                                                          대구광역시 서구
# 1                                                              경상북도
# 2
# 3
# 4                                                          광주광역시 동구
# ..                ...            ...            ...             ...
# 821              전자협상                    2022-00051
# 822              전자협상                    2021-28450
# 823              전자협상                    2022-00260
# 824              전자협상                    2022-00262
# 825              전자협상                    2022-00290
#
#     rgnDutyJntcontrctYn                     chgNtceRsn rbidOpengDt ciblAplYn  \
# 0                     N       취소사유: 공사내용 재검토(신규 공고 추진)                     Y
# 1                     N                  신기술(특허) 내용 추가                     Y
# 2                                                                          N
# 3                                                                          N
# 4                     N  기타 중요한 사항은 반드시 붙임을 참조하시기바랍니다.                     N
# ..                  ...                            ...         ...       ...
# 821
# 822
# 823
# 824
# 825
#
#     mtltyAdvcPsblYn mtltyAdvcPsblYnCnstwkNm
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ..              ...                     ...
# 821
# 822
# 823
# 824
# 825
#
# [8818 rows x 155 columns]
# 입찰공고목록 정보에 대한 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202202010000&inqryEndDt=202202282359&pageNo=14
# 14 page is empty
# dataframe 입찰공고목록 정보에 대한 공사조회 completed
#        bidNtceNo bidNtceOrd reNtceYn            rgstTyNm ntceKindNm intrbidYn  \
# 0    20210912857         01        N  조달청 또는 나라장터 자체 공고건         취소         Y
# 1        2104855         02        N            연계기관 공고건         변경         N
# 2    20211244991         01        N  조달청 또는 나라장터 자체 공고건         변경         N
# 3        2104929         01        N            연계기관 공고건         변경         Y
# 4    20220109217         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# ..           ...        ...      ...                 ...        ...       ...
# 212      LKH0001          1                     연계기관 공고건                    N
# 213      LFH0005          1                     연계기관 공고건                    N
# 214      SDF0009          1                     연계기관 공고건                    N
# 215      HDL0014          1                     연계기관 공고건                    N
# 216      LMP0016          2                     연계기관 공고건       취소공고         N
#
#                bidNtceDt                    refNo  \
# 0    2022-02-25 10:32:39        입찰공고 제2021-244-1호
# 1    2022-02-07 17:05:01
# 2    2022-02-10 13:53:40  부산광역시 동구 공고 제2021-1119호
# 3    2022-02-18 18:05:01
# 4    2022-02-07 09:52:27                210540100
# ..                   ...                      ...
# 212
# 213
# 214
# 215
# 216  2022-02-27 00:00:00
#
#                             bidNtceNm ntceInsttCd  ... d2bMngNgttnStleNm  \
# 0               제주공공하수처리시설 현대화사업(재공고)     B552584  ...
# 1                   천안 스마트공동물류센터 건설공사     B552555  ...
# 2               다어울림 복합문화체육센터 건립 전기공사     3270000  ...
# 3    00사단 기부채납사업(2단계, 도시지역작전훈련장) 건축공사     B552555  ...
# 4                   보성군 복합커뮤니티센터 건립사업     1230141  ...
# ..                                ...         ...  ...               ...
# 212                00여단본부 본청 목욕탕 보수공사              ...              전자협상
# 213                    유격교육대 울타리 보강공사              ...              전자협상
# 214                    22-포-경계시설 개선공사              ...              전자협상
# 215                 22년 POL 유류탱크 세척공사              ...              전자협상
# 216      (대보수 8) 1968-501부대 옥상 등 방수공사              ...
#
#     d2bMngDmndYear d2bMngCnstwkNo   cnstrtsiteRgnNm rgnDutyJntcontrctYn  \
# 0                                  제주특별자치도                            Y
# 1
# 2                                          부산광역시 동구                   N
# 3
# 4                                              전라남도                   Y
# ..             ...            ...               ...                 ...
# 212                    2022-01804
# 213                    2022-01710
# 214                    2022-01724
# 215                    2022-01737
# 216           2022     2022-02081
#
#                                             chgNtceRsn rbidOpengDt ciblAplYn  \
# 0                                              무응찰로 유찰                     Y
# 1                                                                          N
# 2    기초금액 상세 A값 중 국민연금액 수정\r\n[수정전]금14,453,701원\r\n...                     N
# 3                                                                          N
# 4                                BID파일 정정(품질시험비 입력 오류)                     Y
# ..                                                 ...         ...       ...
# 212
# 213
# 214
# 215
# 216
#
#     mtltyAdvcPsblYn mtltyAdvcPsblYnCnstwkNm
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ..              ...                     ...
# 212
# 213
# 214
# 215
# 216
#
# [12205 rows x 155 columns]
# 입찰공고목록 정보에 대한 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=202203010000&inqryEndDt=202203312359&pageNo=22
# 22 page is empty
# dataframe 입찰공고목록 정보에 대한 공사조회 completed
#        bidNtceNo bidNtceOrd reNtceYn            rgstTyNm ntceKindNm intrbidYn  \
# 0    20220125135         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# 1    20220224147         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# 2    B3202200454         01        N            연계기관 공고건         변경         N
# 3    20220229658         01        N  조달청 또는 나라장터 자체 공고건         취소         N
# 4    20220230527         03        N  조달청 또는 나라장터 자체 공고건         변경         N
# ..           ...        ...      ...                 ...        ...       ...
# 537      LHN0013          1                     연계기관 공고건                    N
# 538      MBC0002          1                     연계기관 공고건                    N
# 539      LMG0032          1                     연계기관 공고건       긴급공고         N
# 540      HDP0017          1                     연계기관 공고건                    N
# 541      SCH0013          1                     연계기관 공고건                    N
#
#                bidNtceDt                 refNo  \
# 0    2022-03-03 13:34:38             220000800
# 1    2022-03-29 15:15:50  부산교통공사 공고 제2022-045호
# 2    2022-02-22 14:00:00        B3202200454-01
# 3    2022-03-02 09:17:01      음성군공고 제2022-344호
# 4    2022-03-08 10:23:11       전남농(용두)11405-21
# ..                   ...                   ...
# 537
# 538
# 539  2022-03-10 00:00:00
# 540
# 541
#
#                            bidNtceNm ntceInsttCd  ... d2bMngNgttnStleNm  \
# 0                울산 수소시범도시 수소배관 설치공사     1230130  ...
# 1               1호선 부산대~구서 전차선로 개량공사     B551542  ...
# 2               송산그린시티 동측지구 보도교 건설공사     B500001  ...
# 3                  금왕읍 백야리 군도 선형개량사업     4470000  ...
# 4    정남진 장흥찹쌀 활성화사업(저온보관창고) 신축공사(변경)     Z030550  ...
# ..                               ...         ...  ...               ...
# 537         00여단 GOP대대 법사면 보강공사(2개소)              ...              전자협상
# 538            (22-위-2) 정비고 사무실 보수공사              ...              전자협상
# 539              대규모-02 00부대 지붕 보수공사              ...
# 540           22-노후 소방시설 및 동파방지 개선공사              ...              전자협상
# 541           22-부-16 00전대 간부속소 개선공사              ...              전자협상
#
#     d2bMngDmndYear d2bMngCnstwkNo cnstrtsiteRgnNm rgnDutyJntcontrctYn  \
# 0                                           울산광역시                   N
# 1                                           부산광역시                   Y
# 2
# 3                                        충청북도 음성군                   N
# 4                                        전라남도 장흥군                   N
# ..             ...            ...             ...                 ...
# 537                    2022-02457
# 538                    2022-02534
# 539           2022     2022-02661
# 540                    2022-02689
# 541                    2022-02702
#
#                                             chgNtceRsn rbidOpengDt ciblAplYn  \
# 0              수요기관 요청(부대공 PS항목(토지임대료 등) 오기, 누락, 조정반영)                     Y
# 1                                공고상의 중대한 하자로 인한 공고 취소                     N
# 2                                                                          N
# 3                              입찰서 제출 마감시간 착오입력에 따른 취소                     Y
# 4    관련변경재공고 : 용두농협 입찰공고번호 20220230527-02\r\n\r\n변경...                     Y
# ..                                                 ...         ...       ...
# 537
# 538
# 539
# 540
# 541
#
#     mtltyAdvcPsblYn mtltyAdvcPsblYnCnstwkNm
# 0                 N
# 1                 N
# 2                 N
# 3                 N
# 4                 N
# ..              ...                     ...
# 537
# 538
# 539
# 540
# 541
#
# [20522 rows x 155 columns]
# 입찰공고목록 정보에 대한 공사조회 save compled

# %% [markdown]
# ## 나) 인증키 관련 에러 시 타인증키로 수집

# %%
for each in ServiceKeyLst:
    if flag:
        print("수집완료")
        break
    for i in range(breakPoint, len(BASEPARAM_Lst)):
        if i == len(BASEPARAM_Lst) - 1:
            flag = True
        BASEPARAM_Lst[i]["ServiceKey"] = each
        try:
            resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
            savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
        except Exception as e:
            print(e)
            breakPoint = i
            if e.args[0] == "22":
                print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            else: print(e.args[0])
            break
# Out:
# 1 page scraping start
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay%2B8Hgy660JdC9mVQCFhRKupVGwaw%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay%2B8Hgy660JdC9mVQCFhRKupVGwaw%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5340>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 1 page scraping start
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x%2BMPLarA%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x%2BMPLarA%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 1 page scraping start
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 1 page scraping start
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=gDMXFxO2%2BzC7ZuEFiUXl%2BaWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG%2F0rQ%2Fg%2Fk2elw%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C57C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=gDMXFxO2%2BzC7ZuEFiUXl%2BaWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG%2F0rQ%2Fg%2Fk2elw%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C57C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 1 page scraping start
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /1230000/BidPublicInfoService02/getBidPblancListInfoCnstwk?numOfRows=999&type=json&ServiceKey=6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA%3D%3D&inqryDiv=1&inqryBgnDt=201906010000&inqryEndDt=201906302359&pageNo=1 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000246543C5D30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
print("종료 시점 파라미터키 : ",BASEPARAM_Lst[breakPoint])
print("수집 종료 : ", time.time()-starttime)
# Out:
# 종료 시점 파라미터키 :  {'numOfRows': 999, 'type': 'json', 'ServiceKey': '6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA==', 'inqryDiv': 1, 'inqryBgnDt': '201906010000', 'inqryEndDt': '201906302359', 'pageNo': 1}
# 수집 종료 :  5966.421722412109

# %%
# #다중스레드 수집
# try:
#     starttime = time.time()
#     resultdfList = thread_crawl(BASEPARAM_Lst,URL,SITENAME,DATANAME,SERVICENAME,PAGEYN,scrapy)
#     print("time : ", time.time()-starttime)
# #오류 대비 원스레드 수집
# except Exception as e:
#     print(e)
#     print("multithread error, try onethread")
#     starttime = time.time()
#     resultdfList = []
#     for i in urlList:
#         try :
#             eachdata = getdata(i)
#         except :
#             continue
#         if eachdata is not None:
#             resultdfList.append(eachdata)
#     print("time : ", time.time()-starttime)
