# %% [markdown]
# # 1. 필요 라이브러리 선언

# %%
from datetime import datetime, timedelta
import pandas as pd
import requests
from lxml import html
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote
import os
import time
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %% [markdown]
# # 2. 함수 선언

# %%
### 함수정의: 시작일시(datetime 타입)를 입력 시 한달 후의 시작 및 종료일시를 반환하는 함수
### 파마리터정의:
###   - inDf: 시작일시 (예: datetime(2020,1,1))
def getAfterMonthDate(inDt):
    startYear = inDt.year
    startMonth = inDt.month
    endYear = inDt.year
    endMonth = inDt.month + 1
    if startMonth == 12:
        startYear += 1
        startMonth = 1
        endYear = startYear
        endMonth = startMonth + 1
    elif startMonth == 11:
        startMonth += 1
        endYear = startYear + 1
        endMonth = 1
    else:
        startMonth += 1
        endMonth = startMonth + 1
    outBgnDt = datetime(startYear, startMonth, inDt.day)
    outEndDt = datetime(endYear, endMonth, inDt.day) - timedelta(seconds=1)
    return outBgnDt, outEndDt

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
### 파마리터정의: 
###   - inurl: 메타정보의 "URL"컬럼값 (예: https://www.calspia.go.kr/io/openapi/cm/selectIoCmConstructionList.do )
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
###   - inParam: 메타정보의 "기본키 정보" (예: {'ServiceKey': 't1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g==','type':'json',...}")
###   - inPageYn: 메타정보의 "페이지 정보" (예: 페이지 파라미터 존재 시 1 값")
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
def scrapy(inUrl, inSiteName, inDataName, inServiceName, inParam, inPageYn):
    emptyPd = pd.DataFrame()
    i=1
    while True:
        jsondata = pd.DataFrame()
        print("{} page scraping start".format(i))

        if(inPageYn==1):
            inParam["pageNo"] = i
        queryParams = '?' + urlencode(inParam)

        response = requests.get(inUrl+queryParams)
        
        time.sleep(0.1)
        
        print(inUrl+queryParams)
        response.encoding=STDENCODING
        
        if response.json()["response"]["body"]["totalCount"] == 0:
            print("데이터 없음")
            break

        try:
            jsondata = response.json()["response"]["body"]["items"]
        except Exception as e:
            if e.args[0] == 'Expecting value: line 1 column 1 (char 0)':
                xmlobj = BeautifulSoup(response.text,"lxml-xml")
                errorCode = xmlobj.find("returnReasonCode").text
                raise Exception(errorCode)

        if( jsondata == []):
            print("{} page is empty".format(i))
            break

        rowData = pd.DataFrame(jsondata)
#        print(rowData)
        emptyPd = emptyPd.append(rowData)

        if(inPageYn == 0):
            print("{} no pageNo".format(inPageYn))
            break
        i = i+1

    print("dataframe {} completed".format(inDataName))
    return emptyPd

# %%
### 함수정의: 데이터프레임을 Append 모드로 OUTPUT PATH에 저장하는 함수
### 파마리터정의:  (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
###   - inDf: 저장할 대상 데이터프레임
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
def savedata(inDf, inSiteName, inDataName, inServiceName):
    # DATA SAVE TO THE OUTPUT PATH FOLDER
    outDir = os.path.join(OUTPUTPATH,inSiteName,inDataName)
    outFile = os.path.join( outDir, inServiceName) + ".csv"
    createFolder(outDir)
    if not os.path.exists(outFile):
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="w")
    else:
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="a", header=False)
    print("{} save compled".format(inDataName) )

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수 (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
### 파마리터정의: 
###   - directory: outputpath 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
# def thread_crawl(paramList, inUrl, inSiteName, inDataName, inServiceName, inPageYn, fuction):
#     per_thread_num = 8
#     thread_list = []
#     result_list = []
#     with ThreadPoolExecutor(max_workers=per_thread_num) as exe:
#         for param in paramList:
#             fs = exe.submit(fuction,URL,SITENAME,DATANAME,SERVICENAME,param,PAGEYN)
#             thread_list.append(fs)
#         for execution in concurrent.futures.as_completed(thread_list):
#             df = execution.result()
#             result_list.append(df)
#     return result_list

# %% [markdown]
# # 3. 필요 변수 선언

# %% [markdown]
# ### 가) 메타데이터 업로드

# %%
metadata = pd.read_excel("../../input/datalake_meta22_new.xlsx", sheet_name="2. 조달청-조달정보개방포털", dtype={"순서":str, "비고":str})

# %% [markdown]
# ### 나) output 폴더 생성 변수

# %%
SITENAME = "조달청"

# %%
DATANAME= "계약현황에 대한 일반용역서비스정보조회"

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

# %%
SERVICENAME = targetData["서비스키"].values[0]

# %% [markdown]
# ### 다) 기본키 설정 (서비스별 변경 요)

# %% [markdown]
# #### 1) API KEY

# %%
initServiceKey = "t1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g=="

# %%
ServiceKeyLst = ["hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay+8Hgy660JdC9mVQCFhRKupVGwaw==",\
                 "Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x+MPLarA==",\
                "h2pHFUSHMnsx/wJfhd+fyC4L0X+g16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8/G+twwMfA9m8Q==",\
                "gDMXFxO2+zC7ZuEFiUXl+aWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG/0rQ/g/k2elw==",\
                "6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA=="]

# %% [markdown]
# #### 2) 조회 구분

# %%
inqryDiv = 1

# %% [markdown]
# #### 3) 등록일시 기준 조회 시작일자 및 종료일자

# %%
startYear, startMonth, startDay = 2012, 1, 1
bgnDt = datetime(startYear, startMonth, startDay)
endDt = datetime(startYear, startMonth + 1, startDay) - timedelta(seconds=1)

# %% [markdown]
# #### 4) 조회 rows 수

# %%
numOfRows = 999

# %% [markdown]
# #### 5) 기본키 딕셔너리 생성

# %%
BASEPARAM_KEY = targetData.기본키.values[0].split(",")

# %%
BASEPARAM_Lst = []

# %%
nowDt = datetime.now().strftime("%Y%m%d")

# %%
while True:
    inqryBgnDt = bgnDt.strftime("%Y%m%d")
    inqryEndDt = endDt.strftime("%Y%m%d")
    if inqryBgnDt > nowDt:
        break
    BASEPARAM = {}
    BASEPARAM_VAL = [numOfRows, initServiceKey, inqryDiv, inqryBgnDt, inqryEndDt]
    for i in range(len(BASEPARAM_VAL)):
        BASEPARAM[BASEPARAM_KEY[i]] = BASEPARAM_VAL[i]
        BASEPARAM["type"] = "json"
    BASEPARAM_Lst.append(BASEPARAM)    
    bgnDt, endDt = getAfterMonthDate(bgnDt)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-58fb32b7886b> in <module>
#       7     BASEPARAM_VAL = [numOfRows, initServiceKey, inqryDiv, inqryBgnDt, inqryEndDt]
#       8     for i in range(len(BASEPARAM_VAL)):
# ----> 9         BASEPARAM[BASEPARAM_KEY[i]] = BASEPARAM_VAL[i]
#      10         BASEPARAM["type"] = "json"
#      11     BASEPARAM_Lst.append(BASEPARAM)
#
# IndexError: list index out of range

# %% [markdown]
# ### 5) 함수 파라미터 설정

# %%
URL = targetData["URL"].values[0]

# %%
PAGEYN=1

# %%
STDENCODING='utf-8'

# %% [markdown]
# ### 6) OUTPUT 기본경로 설정

# %%
OUTPUTPATH="../../output"

# %% [markdown]
# # 4. 데이터 수집

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

if os.path.isfile(filePath):
    os.remove(filePath)

# %%
breakPoint = 0

# %% [markdown]
# ## 가) 초기 인증키를 통한 수집

# %%
flag = False

# %%
starttime = time.time()
print("수집시작 : ", time.strftime('%c', time.localtime(time.time())))
for i in range(breakPoint, len(BASEPARAM_Lst)):
    try:
        resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
        print(resultDf)
        savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
    except Exception as e:
        breakPoint = i
        if e.args[0] == "22":
            print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            break
        else:
            print(e)
    if i == len(BASEPARAM_Lst) - 1:
        flag = True
# Out:
# 수집시작 :  Mon Apr  4 12:33:53 2022
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=13
# 13 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 공사조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2011120073008        공사  2011123079300  2011123079300
# 1    2011120109778        공사  2011124569100  2011124569100
# 2    2011070050016        공사  2011072746500  2011072746500
# 3    2011110033104        공사  2011111712500  2011111712500
# 4    2011120022168        공사  2011121010400  2011121010400
# ..             ...       ...            ...            ...
# 292  2013060012993        공사  2012012241105  2012012241105
# 293  2013060089144        공사  2012012570403  2012012570403
# 294  2013060089145        공사  2012012569103  2012012569103
# 295  2013060089638        공사  2012012367802  2012012367802
# 296  2013120011001        공사  2012012488304  2012012488304
#
#                                       cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0    서울난우초외 4교(사당초 동작초 미성초 상도중)급식실개선 및 기타 전기공사            N              신규
# 1                              난우중학교 체육관동 보수공사            N              신규
# 2                           완월초등학교 안전강화학교 구축공사            N              신규
# 3                             노후온실 다겹보온커텐 설치공사            N              신규
# 4                             한밭초 돌봄교실 비디오폰 설치            N              신규
# ..                                         ...          ...             ...
# 292                       군도31호선 백운 1지구 수해복구공사            N              신규
# 293          건봉권역 농촌마을종합개발 HW사업 1단계 전기공사(12년도)            N             계속비
# 294          건봉권역 농촌마을종합개발 HW사업 1단계 통신공사(12년도)            N             계속비
# 295           건봉권역 농촌마을종합개발 1단계 토목건축조경공사(12년도)            N             계속비
# 296                    삼기지구 농업용저수지 둑높이기사업 토목공사            N             계속비
#
#     cntrctCnclsDate   cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0        2012-01-01   착공후 100 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-03-31
# 1        2012-01-01    착공후 90 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-03-28
# 2        2012-01-02    착공후 30 일  지방계약법 (022조 00항 03호 1-목)  ...     2011-08-20
# 3        2012-01-02    착공후 31 일  국가계약법 (023조 01항 08호 0-목)  ...     2011-12-15
# 4        2012-01-02  계약체결후 15 일  지방계약법 (025조 01항 05호 0-목)  ...     2011-12-07
# ..              ...         ...                       ...  ...            ...
# 292      2012-01-31   착공후 365 일  지방계약법 (012조 00항 00호 0-목)  ...     2013-06-22
# 293      2012-01-31   착공후 639 일  국가계약법 (010조 01항 00호 0-목)  ...     2014-06-30
# 294      2012-01-31   착공후 648 일  국가계약법 (010조 01항 00호 0-목)  ...     2014-06-30
# 295      2012-01-31   착공후 323 일  국가계약법 (010조 01항 00호 0-목)  ...     2014-06-30
# 296      2012-01-31   착공후 302 일  국가계약법 (021조 01항 02호 0-목)  ...     2013-12-20
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                 ...              ...             ...
# 292
# 293
# 294
# 295
# 296
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                  ...
# 292
# 293
# 294
# 295
# 296
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 292
# 293
# 294
# 295
# 296
#
# [11286 rows x 47 columns]
# 나라장터검색조건에 의한 계약현황 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=28
# 28 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 공사조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2012010022337        공사     1221002401      122100802
# 1    2012020001768        공사  2012020101200  2012020101200
# 2    2012010028020        공사  2012011703100  2012011703100
# 3    2012010031507        공사  2012011892700  2012011892700
# 4    2012010034606        공사  2012012081800  2012012081800
# ..             ...       ...            ...            ...
# 289  2014050091560        공사  2012026336609  2012026336609
# 290  2014060085057        공사  2012026680207  2012026680207
# 291  2014090049053        공사  2012028394001  2012028394001
# 292  2014090061012        공사  2012026680208  2012026680208
# 293  2014110055351        공사  2012026680209  2012026680209
#
#                         cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm cntrctCnclsDate  \
# 0         명례일반산업단지 진입도로  건설공사 2차            Y              장기      2012-02-01
# 1    전남여고 역사관 화장실 환경개선(건축,설비) 공사            N              신규      2012-02-01
# 2             서울월정초등학교 조회대 보수 공사            N              신규      2012-02-01
# 3                     놀이시설물 보수공사            N              신규      2012-02-01
# 4            온고지신 마을만들기 사업 건축 공사            N              신규      2012-02-01
# ..                           ...          ...             ...             ...
# 289              전포로-하마정간 도로확장공사            N              신규      2012-02-29
# 290       공정지구 농업용저수지둑높이기사업 토목공사            Y             계속비      2012-02-29
# 291          화북 죽전2리 마을진입로 확포장공사            N              신규      2012-02-29
# 292       공정지구 농업용저수지둑높이기사업 토목공사            Y             계속비      2012-02-29
# 293       공정지구 농업용저수지둑높이기사업 토목공사            Y             계속비      2012-02-29
#
#                      cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0    공사기간 : 착공후 금차 340일, 총공사 일                     국가계약법  ...     2014-04-12
# 1                     착공후 36 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-03-08
# 2                     착공후 25 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-24
# 3                   계약체결후 30 일  국가계약법 (026조 01항 05호 가-목)  ...     2012-02-27
# 4                    착공후 120 일  지방계약법 (012조 00항 00호 0-목)  ...     2012-05-31
# ..                         ...                       ...  ...            ...
# 289                  착공후 730 일  지방계약법 (012조 00항 00호 0-목)  ...     2014-06-08
# 290                  착공후 291 일    국가계약법 (010조 01항 00호 목)  ...     2014-09-30
# 291                  착공후 180 일  지방계약법 (025조 01항 05호 0-목)  ...     2015-01-06
# 292                  착공후 291 일    국가계약법 (010조 01항 00호 목)  ...     2014-11-20
# 293                  착공후 291 일    국가계약법 (010조 01항 00호 목)  ...     2014-12-10
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                 ...              ...             ...
# 289
# 290
# 291
# 292
# 293
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                  ...
# 289
# 290
# 291
# 292
# 293
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 289
# 290
# 291
# 292
# 293
#
# [26268 rows x 47 columns]
# 나라장터검색조건에 의한 계약현황 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=29
# 30 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=30
# 31 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=31
# 32 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=32
# 33 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=33
# 34 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=34
# 35 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=35
# 36 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=36
# 37 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=37
# 38 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=38
# 39 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=39
# 40 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=40
# 40 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 공사조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2012020048661        공사  2012023034100  2012023034100
# 1    2012020061615        공사  2012023979100  2012023979100
# 2    2012020062654        공사  2012024055800  2012024055800
# 3    2012020078150        공사  2012025290000  2012025290000
# 4    2012020082230        공사  2012025666100  2012025666100
# ..             ...       ...            ...            ...
# 914  2014120110449        공사  2012036556206  2012036556206
# 915  2015030019981        공사  2012036895804  2012036895804
# 916  2015060047970        공사  2012036556207  2012036556207
# 917  2015070046777        공사  2012036556208  2012036556208
# 918  2015030018986        공사  2012036895803  2012036895803
#
#                               cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0    배광용한약방옆 도시계획도로(소로2-65호선) 가로등 설치공사            N              신규
# 1                 성주군 종합사회복지관 건축공사(2차)            N             계속비
# 2                전주서곡중학교 복도(1,4층) 도장공사            N              신규
# 3                          꿈누리 교실 리모델링            N              신규
# 4                   서울 성북초등학교 상담실 설치공사            N              신규
# ..                                 ...          ...             ...
# 914              염산면소재지 종합정비사업 건축물철거공사            N              신규
# 915             하빈지구(현내-감문) 수해상습지 개선사업            N              장기
# 916              염산면소재지 종합정비사업 건축물철거공사            N              신규
# 917              염산면소재지 종합정비사업 건축물철거공사            N              신규
# 918             하빈지구(현내-감문) 수해상습지 개선사업            N              장기
#
#     cntrctCnclsDate  cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0        2012-03-01   착공후 25 일  지방계약법 (010조 01항 00호 0-목)  ...     2012-03-29
# 1        2012-03-01  착공후 365 일  지방계약법 (012조 00항 00호 0-목)  ...     2012-11-16
# 2        2012-03-01    착공후 7 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-29
# 3        2012-03-01    착공후 6 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-29
# 4        2012-03-01   착공후 10 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-29
# ..              ...        ...                       ...  ...            ...
# 914      2012-03-30  착공후 180 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-08-31
# 915      2012-03-30  착공후 900 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-02-27
# 916      2012-03-30  착공후 180 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-08-31
# 917      2012-03-30  착공후 180 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-12-31
# 918      2012-03-30  착공후 900 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-02-27
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                 ...              ...             ...
# 914
# 915
# 916
# 917
# 918
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                  ...
# 914
# 915
# 916
# 917
# 918
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 914
# 915
# 916
# 917
# 918
#
# [38881 rows x 47 columns]
# 나라장터검색조건에 의한 계약현황 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=29
# 30 page scraping start
# ...
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=29
# 30 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=30
# 31 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=31
# 32 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=32
# 33 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=33
# 34 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=34
# 35 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=35
# 36 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=36
# 37 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=37
# 38 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=38
# 39 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=39
# 40 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=40
# 41 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150401&inqryEndDate=20150430&pageNo=41
# 41 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 공사조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2015050002822        공사  2015040203901  2015040203901
# 1    2015030053437        공사  2015033242000  2015033242000
# 2    2015030053445        공사  2015033243900  2015033243900
# 3    2015030103728        공사  2015036421000  2015036421000
# 4    2015030103729        공사  2015036421100  2015036421100
# ..             ...       ...            ...            ...
# 387  2016090042856        공사  2015046631307  2015046631307
# 388  2016110021188        공사  2015047130003  2015047130003
# 389  2016110162255        공사  2015047026003  2015047026003
# 390  2016120112560        공사  2015047244301  2015047244301
# 391  2016120136206        공사  2015046466804  2015046466804
#
#                                       cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0                                 이천마을 농로 포장공사            N              신규
# 1                         서운중학교 교무실이전관련 키폰설치공사            N              신규
# 2         과천문원중  내부칸막이 설치로 인한 전기공사(5층서고,2층서버실)            N              신규
# 3                        증산면 동안리 가리골 외 농로 포장공사            N              신규
# 4                      증산면 황항리 아랫임평길 외 농로 포장공사            N              신규
# ..                                         ...          ...             ...
# 387                  목재문화체험장 조성공사(토목·건축분야) 4차분            N             계속비
# 388                        농촌농업생활용수 개발사업(동수지구)            N              신규
# 389  BTL외지역 분류식 오수관거 설치 전기공사(총괄 1회 및 1차 1회 변경)            N              장기
# 390                       복하천 제2수변공원 조성사업 전기공사            N              신규
# 391                                경주 불국사 정비공사            N              신규
#
#     cntrctCnclsDate  cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0        2015-04-01   착공후 30 일  지방계약법 (022조 00항 03호 1-목)  ...     2015-05-02
# 1        2015-04-01    착공후 7 일  지방계약법 (022조 00항 07호 0-목)  ...     2015-03-22
# 2        2015-04-01    착공후 4 일  지방계약법 (025조 01항 05호 0-목)  ...     2015-04-06
# 3        2015-04-01   착공후 50 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-05-22
# 4        2015-04-01   착공후 50 일  지방계약법 (012조 00항 00호 0-목)  ...     2015-05-22
# ..              ...        ...                       ...  ...            ...
# 387      2015-04-30  착공후 980 일  지방계약법 (020조 01항 06호 0-목)  ...     2016-08-26
# 388      2015-04-30  착공후 180 일  지방계약법 (025조 01항 05호 0-목)  ...     2016-11-16
# 389      2015-04-30  착공후 990 일  지방계약법 (012조 00항 00호 0-목)  ...     2018-01-17
# 390      2015-04-30   착공후 90 일  지방계약법 (025조 01항 05호 0-목)  ...     2017-02-22
# 391      2015-04-30  착공후 180 일  지방계약법 (012조 00항 00호 0-목)  ...     2016-12-31
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                 ...              ...             ...
# 387
# 388
# 389
# 390
# 391
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0                                  시설공사            시설물유지관리공사
# 1                                  시설공사                 개별법령
# 2                                  시설공사                 개별법령
# 3                                  시설공사            시설물유지관리공사
# 4                                  시설공사            시설물유지관리공사
# ..             ...                  ...                  ...
# 387                                시설공사                 종합건설
# 388                                시설공사                 종합건설
# 389                                시설공사                 개별법령
# 390                                시설공사                 개별법령
# 391                                시설공사                 개별법령
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0            72152799          철근콘크리트공사
# 1            72151699            정보통신공사
# 2            72151597              전기공사
# 3            72152799          철근콘크리트공사
# 4            72152799          철근콘크리트공사
# ..                ...               ...
# 387          72149001              토목공사
# 388          72149001              토목공사
# 389          72151597              전기공사
# 390          72151597              전기공사
# 391          72101599           문화재수리공사
#
# [39353 rows x 47 columns]
# 나라장터검색조건에 의한 계약현황 공사조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20150501&inqryEndDate=20150531&pageNo=15
# 16 page scraping start

# %% [markdown]
# ## 나) 인증키 관련 에러 시 타인증키로 수집

# %%
for each in ServiceKeyLst:
    if flag:
        print("수집완료")
        break
    for i in range(breakPoint, len(BASEPARAM_Lst)):
        if i == len(BASEPARAM_Lst) - 1:
            flag = True
        BASEPARAM_Lst[i]["ServiceKey"] = each
        try:
            resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
            print(resultDf)
            savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
        except Exception as e:
            print(e)
            breakPoint = i
            if e.args[0] == "22":
                print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            elif e.args[0] == "01":
                print("제공기관 서비스 제공 상태가 원활하지 않습니다.")
            else:
                print(e.args[0])
            break

# %%
print("종료 시점 파라미터키 : ",BASEPARAM_Lst[breakPoint])
print("수집 종료 : ", time.time()-starttime)

# %%
# #다중스레드 수집
# try:
#     starttime = time.time()
#     resultdfList = thread_crawl(BASEPARAM_Lst,URL,SITENAME,DATANAME,SERVICENAME,PAGEYN,scrapy)
#     print("time : ", time.time()-starttime)
# #오류 대비 원스레드 수집
# except Exception as e:
#     print(e)
#     print("multithread error, try onethread")
#     starttime = time.time()
#     resultdfList = []
#     for i in urlList:
#         try :
#             eachdata = getdata(i)
#         except :
#             continue
#         if eachdata is not None:
#             resultdfList.append(eachdata)
#     print("time : ", time.time()-starttime)
