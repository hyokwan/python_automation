# %% [markdown]
# # 1. 필요 라이브러리 선언

# %%
from datetime import datetime, timedelta
import pandas as pd
import requests
from lxml import html
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote
import os
import time
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %% [markdown]
# # 2. 함수 선언

# %%
### 함수정의: 시작일시(datetime 타입)를 입력 시 한달 후의 시작 및 종료일시를 반환하는 함수
### 파마리터정의:
###   - inDf: 시작일시 (예: datetime(2020,1,1))
def getAfterMonthDate(inDt):
    startYear = inDt.year
    startMonth = inDt.month
    endYear = inDt.year
    endMonth = inDt.month + 1
    if startMonth == 12:
        startYear += 1
        startMonth = 1
        endYear = startYear
        endMonth = startMonth + 1
    elif startMonth == 11:
        startMonth += 1
        endYear = startYear + 1
        endMonth = 1
    else:
        startMonth += 1
        endMonth = startMonth + 1
    outBgnDt = datetime(startYear, startMonth, inDt.day)
    outEndDt = datetime(endYear, endMonth, inDt.day) - timedelta(seconds=1)
    return outBgnDt, outEndDt

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
### 파마리터정의: 
###   - inurl: 메타정보의 "URL"컬럼값 (예: https://www.calspia.go.kr/io/openapi/cm/selectIoCmConstructionList.do )
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
###   - inParam: 메타정보의 "기본키 정보" (예: {'ServiceKey': 't1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g==','type':'json',...}")
###   - inPageYn: 메타정보의 "페이지 정보" (예: 페이지 파라미터 존재 시 1 값")
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
def scrapy(inUrl, inSiteName, inDataName, inServiceName, inParam, inPageYn):
    emptyPd = pd.DataFrame()
    i=1
    while True:
        jsondata = pd.DataFrame()
        print("{} page scraping start".format(i))

        if(inPageYn==1):
            inParam["pageNo"] = i
        queryParams = '?' + urlencode(inParam)

        response = requests.get(inUrl+queryParams)
        
        time.sleep(0.1)
        
        print(inUrl+queryParams)
        response.encoding=STDENCODING
        
        if response.json()["response"]["body"]["totalCount"] == 0:
            print("데이터 없음")
            break

        try:
            jsondata = response.json()["response"]["body"]["items"]
        except Exception as e:
            if e.args[0] == 'Expecting value: line 1 column 1 (char 0)':
                xmlobj = BeautifulSoup(response.text,"lxml-xml")
                errorCode = xmlobj.find("returnReasonCode").text
                raise Exception(errorCode)

        if( jsondata == []):
            print("{} page is empty".format(i))
            break

        rowData = pd.DataFrame(jsondata)
#        print(rowData)
        emptyPd = emptyPd.append(rowData)

        if(inPageYn == 0):
            print("{} no pageNo".format(inPageYn))
            break
        i = i+1

    print("dataframe {} completed".format(inDataName))
    return emptyPd

# %%
### 함수정의: 데이터프레임을 Append 모드로 OUTPUT PATH에 저장하는 함수
### 파마리터정의:  (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
###   - inDf: 저장할 대상 데이터프레임
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
def savedata(inDf, inSiteName, inDataName, inServiceName):
    # DATA SAVE TO THE OUTPUT PATH FOLDER
    outDir = os.path.join(OUTPUTPATH,inSiteName,inDataName)
    outFile = os.path.join( outDir, inServiceName) + ".csv"
    createFolder(outDir)
    if not os.path.exists(outFile):
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="w")
    else:
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="a", header=False)
    print("{} save compled".format(inDataName) )

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수 (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
### 파마리터정의: 
###   - directory: outputpath 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
# def thread_crawl(paramList, inUrl, inSiteName, inDataName, inServiceName, inPageYn, fuction):
#     per_thread_num = 8
#     thread_list = []
#     result_list = []
#     with ThreadPoolExecutor(max_workers=per_thread_num) as exe:
#         for param in paramList:
#             fs = exe.submit(fuction,URL,SITENAME,DATANAME,SERVICENAME,param,PAGEYN)
#             thread_list.append(fs)
#         for execution in concurrent.futures.as_completed(thread_list):
#             df = execution.result()
#             result_list.append(df)
#     return result_list

# %% [markdown]
# # 3. 필요 변수 선언

# %% [markdown]
# ### 가) 메타데이터 업로드

# %%
metadata = pd.read_excel("../../input/datalake_meta22.xlsx", sheet_name="2. 조달청-조달정보개방포털", dtype={"순서":str, "비고":str})

# %% [markdown]
# ### 나) output 폴더 생성 변수

# %%
SITENAME = "조달청"

# %%
DATANAME= "계약현황에 대한 공사변경이력조회"

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

# %%
SERVICENAME = targetData["서비스키"].values[0]

# %% [markdown]
# ### 다) 기본키 설정 (서비스별 변경 요)

# %% [markdown]
# #### 1) API KEY

# %%
initServiceKey = "t1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g=="

# %%
ServiceKeyLst = ["hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay+8Hgy660JdC9mVQCFhRKupVGwaw==",\
                 "Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x+MPLarA==",\
                "h2pHFUSHMnsx/wJfhd+fyC4L0X+g16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8/G+twwMfA9m8Q==",\
                "gDMXFxO2+zC7ZuEFiUXl+aWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG/0rQ/g/k2elw==",\
                "6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA=="]

# %% [markdown]
# #### 2) 조회 구분

# %%
inqryDiv = 1

# %% [markdown]
# #### 3) 변경일시 기준 조회 시작일자 및 종료일자

# %%
startYear, startMonth, startDay = 2012, 1, 1
bgnDt = datetime(startYear, startMonth, startDay)
endDt = datetime(startYear, startMonth + 1, startDay) - timedelta(seconds=1)

# %% [markdown]
# #### 4) 조회 rows 수

# %%
numOfRows = 999

# %% [markdown]
# #### 5) 기본키 딕셔너리 생성

# %%
BASEPARAM_KEY = targetData.기본키.values[0].split(",")

# %%
BASEPARAM_Lst = []

# %%
nowDt = datetime.now().strftime("%Y%m%d%H%M")

# %%
while True:
    inqryBgnDt = bgnDt.strftime("%Y%m%d%H%M")
    inqryEndDt = endDt.strftime("%Y%m%d%H%M")
    if inqryBgnDt > nowDt:
        break
    BASEPARAM = {}
    BASEPARAM_VAL = [numOfRows, initServiceKey, inqryDiv, inqryBgnDt, inqryEndDt]
    for i in range(len(BASEPARAM_VAL)):
        BASEPARAM[BASEPARAM_KEY[i]] = BASEPARAM_VAL[i]
        BASEPARAM["type"] = "json"
    BASEPARAM_Lst.append(BASEPARAM)    
    bgnDt, endDt = getAfterMonthDate(bgnDt)

# %% [markdown]
# ### 5) 함수 파라미터 설정

# %%
URL = targetData["URL"].values[0]

# %%
PAGEYN=1

# %%
STDENCODING='utf-8'

# %% [markdown]
# ### 6) OUTPUT 기본경로 설정

# %%
OUTPUTPATH="../../output"

# %% [markdown]
# # 4. 데이터 수집

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

if os.path.isfile(filePath):
    os.remove(filePath)

# %%
breakPoint = 0

# %% [markdown]
# ## 가) 초기 인증키를 통한 수집

# %%
flag = False

# %%
starttime = time.time()
print("수집시작 : ", time.strftime('%c', time.localtime(time.time())))
for i in range(breakPoint, len(BASEPARAM_Lst)):
    try:
        resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
        print(resultDf)
        savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
    except Exception as e:
        breakPoint = i
        if e.args[0] == "22":
            print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            break
        else:
            print(e)
    if i == len(BASEPARAM_Lst) - 1:
        flag = True
# Out:
# 수집시작 :  Mon Apr  4 17:56:24 2022
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201201010000&inqryEndDt=201201312359&pageNo=12
# 12 page is empty
# dataframe 계약현황에 대한 공사변경이력조회 completed
#       untyCntrctNo bsnsDivNm         dcsnCntrctNo          cntrctRefNo  \
# 0    2011120109778        공사        2011124569100        2011124569100
# 1    2011120124501        공사        2011112232301        2011112232301
# 2    2012010000162        공사  ex20124111001100101  ex20124111001100101
# 3    2011120116474        공사        2011121801401        2011121801401
# 4    2011120073008        공사        2011123079300        2011123079300
# ..             ...       ...                  ...                  ...
# 998  2012010043863        공사        2012012645600        2012012645600
# 0    2012010046375        공사        2012012796500        2012012796500
# 1    2012010044248        공사        2012012667100        2012012667100
# 2    2012010039657        공사        2012012392500        2012012392500
# 3    2012010040334        공사        2012012434400        2012012434400
#
#                                       cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0                              난우중학교 체육관동 보수공사            N              신규
# 1                               청사 옥상녹화사업 전기공사            N              신규
# 2                    2012년 공주지사 건물기계설비 유지관리 도급            Y              신규
# 3                      상현중 교사동(본관동 별관동) 창호교체공사            N              신규
# 4    서울난우초외 4교(사당초 동작초 미성초 상도중)급식실개선 및 기타 전기공사            N              신규
# ..                                         ...          ...             ...
# 998                         호산고등학교 기숙사 증축 전기공사            N              신규
# 0         경인교육대학교 계양생활관(2관) 선풍기 이설 및 통신선로 마감공사            N              신규
# 1                             담장휀스 설치 및 현관문 교체            N              신규
# 2                    문산초등학교 휀스 설치공사 소액소의 견적 공고            N              신규
# 3                       하동체육관 강당무대 와이어 드럼 교체공사            N              신규
#
#     cntrctCnclsDate  cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0        2012-01-01   착공후 90 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-03-28
# 1        2011-11-16   착공후 45 일  지방계약법 (025조 01항 05호 0-목)  ...     2011-12-31
# 2        2012-01-02                                국가계약법  ...
# 3        2011-12-20   착공후 60 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-20
# 4        2012-01-01  착공후 100 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-03-31
# ..              ...        ...                       ...  ...            ...
# 998      2012-01-31  착공후 194 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-08-17
# 0        2012-01-31   착공후 10 일  국가계약법 (026조 01항 05호 가-목)  ...     2012-02-10
# 1        2012-01-31    착공후 5 일  지방계약법 (022조 00항 07호 0-목)  ...     2012-02-04
# 2        2012-01-31   착공후 25 일  지방계약법 (022조 00항 02호 1-목)  ...     2012-02-24
# 3        2012-01-31   착공후 25 일  지방계약법 (022조 00항 07호 1-목)  ...     2012-02-26
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2        한국도로공사
# 3
# 4
# ..          ...                 ...              ...             ...
# 998
# 0
# 1
# 2
# 3
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                  ...
# 998
# 0
# 1
# 2
# 3
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 998
# 0
# 1
# 2
# 3
#
# [9994 rows x 47 columns]
# 계약현황에 대한 공사변경이력조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201202010000&inqryEndDt=201202292359&pageNo=23
# 23 page is empty
# dataframe 계약현황에 대한 공사변경이력조회 completed
#      untyCntrctNo bsnsDivNm         dcsnCntrctNo          cntrctRefNo  \
# 0   2012020000105        공사                           공사-201100133-02
# 1   2012020000107        공사                           공사-201100132-02
# 2   2012010045185        공사  ex20123001301100301  ex20123001301100301
# 3   2012010046062        공사  ex20124106001200101  ex20124106001200101
# 4   2012020001621        공사       3101002012C001     0000000000730400
# ..            ...       ...                  ...                  ...
# 15  2012020103407        공사        2012027332200        2012027332200
# 16  2012020126189        공사        2012029169800        2012029169800
# 17  2012020118944        공사        2012028647800        2012028647800
# 18  2012020114822        공사        2011123335601        2011123335601
# 19  2012020125234        공사        2012029101700        2012029101700
#
#                        cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm cntrctCnclsDate  \
# 0    경인 아라뱃길 인천터미널 물류단지 조성 전기공사            Y              신규
# 1     경인 아라뱃길 김포고촌 물류단지 조성 전기공사            Y              신규
# 2   고속국도 제65호선 주문진-속초 전기공사(4공구)            N              신규      2012-02-01
# 3          2012년 무주지사 관내 사고복구공사            Y              신규      2012-02-01
# 4      2012년도 고양 삼송 배전설비 유지보수공사            N              신규      2012-02-01
# ..                          ...          ...             ...             ...
# 15         2012년 사방댐설치사업(송천사방댐)            N              신규      2012-02-29
# 16     교무실 재배치 인터폰 설치 관련 케이블 공사            N              신규      2012-02-29
# 17             과천고 음향점검 및 구축 계약            N              신규      2012-02-29
# 18            광양평생교육관 리모델링 소방공사            N              신규      2011-12-22
# 19                   급식실제습기설치공사            N              신규      2012-02-29
#
#      cntrctPrd                 baseLawNm  ... ttalCcmpltDate linkInsttNm  \
# 0    2011-0299                   투자기관기본법  ...                    한국수자원공사
# 1    2011-0297                   투자기관기본법  ...                    한국수자원공사
# 2                                  국가계약법  ...                     한국도로공사
# 3                                  국가계약법  ...                     한국도로공사
# 4                                  국가계약법  ...                   한국지역난방공사
# ..         ...                       ...  ...            ...         ...
# 15    착공후 90 일  국가계약법 (026조 01항 05호 마-목)  ...     2012-06-02
# 16     착공후 1 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-29
# 17     착공후 1 일  지방계약법 (022조 00항 03호 1-목)  ...     2012-03-07
# 18    착공후 65 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-02-29
# 19  계약체결후 10 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-03-09
#
#    d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm d2bMngCnstwkNo  \
# 0
# 1
# 2
# 3
# 4
# ..                 ...              ...             ...            ...
# 15
# 16
# 17
# 18
# 19
#
#    pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm pubPrcrmntClsfcNo  \
# 0
# 1
# 2
# 3
# 4
# ..                  ...                  ...               ...
# 15
# 16
# 17
# 18
# 19
#
#    pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 15
# 16
# 17
# 18
# 19
#
# [20999 rows x 47 columns]
# 계약현황에 대한 공사변경이력조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201203010000&inqryEndDt=201203312359&pageNo=28
# 28 page is empty
# dataframe 계약현황에 대한 공사변경이력조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2012020096182        공사  2012026745500  2012026745500
# 1    2012020098717        공사  2012026968600  2012026968600
# 2    2012020116771        공사  2012028440500  2012028440500
# 3    2012020120408        공사  2012028719900  2012028719900
# 4    2012030000074        공사  2012030002500  2012030002500
# ..             ...       ...            ...            ...
# 128  2012030100487        공사  2012036557100  2012036557100
# 129  2012030100493        공사  2012036559200  2012036559200
# 130  2012030100533        공사  2012036563000  2012036563000
# 131  2012030100571        공사  2012036565300  2012036565300
# 132  2012030106660        공사  2012036981200  2012036981200
#
#                       cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm cntrctCnclsDate  \
# 0            센텀중학교 일원 보행환경개선사업            N              신규      2012-03-01
# 1            2012 가로수 결식지 보식공사            N              신규      2012-03-01
# 2                 성수2리 배수로정비공사            N              신규      2012-03-01
# 3           서울중마초등학교 돌봄교실 전기공사            N              신규      2012-03-01
# 4            방화선지역 내 낙엽긁기 공사실시            N              신규      2012-03-01
# ..                         ...          ...             ...             ...
# 128                   갈동천 정비공사            N              신규      2012-03-31
# 129                   성유천 정비공사            N              신규      2012-03-31
# 130                  달지1천 정비공사            N              신규      2012-03-31
# 131                   보림천 정비공사            N              신규      2012-03-31
# 132  화장실(1~5층)소변기 칸막이 설치 공사의 건            N              신규      2012-03-30
#
#      cntrctPrd                 baseLawNm  ... ttalCcmpltDate linkInsttNm  \
# 0     착공후 60 일  지방계약법 (022조 00항 07호 1-목)  ...     2012-04-30
# 1     착공후 20 일  지방계약법 (022조 00항 07호 1-목)  ...     2012-03-25
# 2     착공후 60 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-05-04
# 3     착공후 15 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-03-15
# 4     착공후 10 일  국가계약법 (043조 00항 00호 0-목)  ...     2012-03-10
# ..         ...                       ...  ...            ...         ...
# 128  착공후 180 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-10-01
# 129  착공후 180 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-10-01
# 130  착공후 180 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-10-01
# 131  착공후 180 일  지방계약법 (020조 01항 06호 0-목)  ...     2012-10-01
# 132    착공후 1 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-04-01
#
#     d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm d2bMngCnstwkNo  \
# 0
# 1
# 2
# 3
# 4
# ..                  ...              ...             ...            ...
# 128
# 129
# 130
# 131
# 132
#
#     pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm pubPrcrmntClsfcNo  \
# 0
# 1
# 2
# 3
# 4
# ..                   ...                  ...               ...
# 128
# 129
# 130
# 131
# 132
#
#     pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...
# 128
# 129
# 130
# 131
# 132
#
# [26107 rows x 47 columns]
# 계약현황에 대한 공사변경이력조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201204010000&inqryEndDt=201204302359&pageNo=26
# 26 page is empty
# dataframe 계약현황에 대한 공사변경이력조회 completed
#      untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0   2012030106075        공사  2012036941400  2012036941400
# 1   2012030106348        공사  2012030044201  2012030044201
# 2   2012030099983        공사  2012036521300  2012036521300
# 3   2012030100782        공사  2012036581700  2012036581700
# 4   2012030104796        공사  2012036850900  2012036850900
# ..            ...       ...            ...            ...
# 58  2012040104126        공사  2012046770400  2012046770400
# 59  2012040095352        공사  2011124431701  2011124431701
# 60  2012040095618        공사  2012046174000  2012046174000
# 61  2012040099633        공사  2012046467500  2012046467500
# 62  2012040096958        공사  2012046261100  2012046261100
#
#                            cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0     양덕2동 주민센터 부속건물 증축 공사(건축 기계설비)            N              신규
# 1                    갈운1리 가드레일 설치공사            N              신규
# 2                   명서2동 주민복지관 건축공사            N              신규
# 3                진동면 진동시외버스정류장 이설공사            N              신규
# 4               오봉사 삼거리 자전거신호등 설치공사            N              신규
# ..                              ...          ...             ...
# 58            원당1통 보도블럭 및 우수박스 보수공사            N              신규
# 59  대방동 제비어울림공원 조성공사(주계약자공동도급방식-긴급)            Y              신규
# 60                 2012년 자투리공원 조성사업            N              신규
# 61            대통령기 요트경기대회 슬립웨이 설치공사            N              신규
# 62                       연산소하천 정비공사            N              신규
#
#    cntrctCnclsDate  cntrctPrd                 baseLawNm  ... ttalCcmpltDate  \
# 0       2012-04-01   착공후 90 일  지방계약법 (022조 00항 02호 1-목)  ...     2012-06-30
# 1       2012-03-04   착공후 25 일  지방계약법 (022조 00항 07호 0-목)  ...     2012-04-09
# 2       2012-04-01  착공후 180 일  지방계약법 (012조 00항 00호 0-목)  ...     2012-10-02
# 3       2012-04-01   착공후 25 일  지방계약법 (012조 00항 00호 0-목)  ...     2012-04-28
# 4       2012-04-01   착공후 60 일  지방계약법 (012조 00항 00호 0-목)  ...     2012-06-03
# ..             ...        ...                       ...  ...            ...
# 58      2012-04-30    착공후 7 일  지방계약법 (022조 00항 03호 1-목)  ...     2012-05-06
# 59      2011-12-29  착공후 120 일  지방계약법 (020조 01항 07호 0-목)  ...     2012-04-30
# 60      2012-04-30   착공후 45 일  지방계약법 (025조 01항 05호 0-목)  ...     2012-06-15
# 61      2012-04-30   착공후 25 일  지방계약법 (022조 00항 07호 1-목)  ...     2012-05-26
# 62      2012-04-30  착공후 300 일  지방계약법 (012조 00항 00호 0-목)  ...     2013-02-27
#
#    linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..         ...                 ...              ...             ...
# 58
# 59
# 60
# 61
# 62
#
#    d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm pubPrcrmntClsfcNo  \
# 0
# 1
# 2
# 3
# 4
# ..            ...                  ...                  ...               ...
# 58
# 59
# 60
# 61
# 62
#
#    pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..               ...
# 58
# 59
# 60
# 61
# 62
#
# [24039 rows x 47 columns]
# 계약현황에 대한 공사변경이력조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201205010000&inqryEndDt=201205312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201205010000&inqryEndDt=201205312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201205010000&inqryEndDt=201205312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201205010000&inqryEndDt=201205312359&pageNo=4
# 5 page scraping start
# ...
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=29
# 30 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=30
# 31 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=31
# 32 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=32
# 33 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=33
# 34 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=34
# 35 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=35
# 36 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=36
# 37 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=37
# 38 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=38
# 39 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=39
# 40 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=40
# 41 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=41
# 42 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=42
# 43 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=43
# 44 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=44
# 45 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=45
# 46 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=46
# 47 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=47
# 48 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=48
# 49 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=49
# 50 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=50
# 51 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=51
# 52 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=52
# 53 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201711010000&inqryEndDt=201711302359&pageNo=53
# 53 page is empty
# dataframe 계약현황에 대한 공사변경이력조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2017100182258        공사  2017100DF5A00  2017100DF5A00
# 1    2017100173964        공사                 2017100D47000
# 2    2017100181465        공사  2017100DDFC00  2017100DDFC00
# 3    2017100188302        공사  201705017DD01  201705017DD01
# 4    2017100183456        공사  2017029899202  2017029899202
# ..             ...       ...            ...            ...
# 877  2017110218184        공사  20171111CEA00  20171111CEA00
# 878  2017110218210        공사  20171111CF300  20171111CF300
# 879  2017110218212        공사  20171111CF600  20171111CF600
# 880  2017110238946        공사  201711130A900  201711130A900
# 881  2017110239188        공사  201711130FE00  201711130FE00
#
#                         cnstwkNm cmmnCntrctYn lngtrmCtnuDivNm cntrctCnclsDate  \
# 0      국도5호선 안동 ~ 의성간 안전시설물 정비공사            N              신규      2017-11-01
# 1                   전기 온수기 설치 공사            N              신규
# 2            한라중계펌프장 MCC제어반 교체공사            N              신규      2017-10-31
# 3                      내안계교 확장사업            N              신규      2017-10-31
# 4    지방도863호선 갓길 정비사업(여수 율촌)-2차분            N             계속비      2017-10-31
# ..                           ...          ...             ...             ...
# 877               북평 동해 농로 확포장공사            N              신규      2017-11-30
# 878                 해남 부호 농로포장공사            N              신규      2017-11-30
# 879                해남 호천 농로 정비공사            N              신규      2017-11-30
# 880              마산 육일시 하수도 정비공사            N              신규      2017-11-30
# 881              해남 온인 용배수로 정비공사            N              신규      2017-11-30
#
#      cntrctPrd                 baseLawNm  ... ttalCcmpltDate linkInsttNm  \
# 0     착공후 60 일  국가계약법 (021조 01항 06호 0-목)  ...     2018-01-04
# 1      착공후 8 일  지방계약법 (025조 01항 05호 0-목)  ...     2017-11-07
# 2     착공후 28 일  지방계약법 (022조 00항 07호 1-목)  ...     2017-11-28
# 3     착공후 60 일  지방계약법 (012조 00항 00호 0-목)  ...     2017-11-03
# 4    착공후 360 일  지방계약법 (012조 00항 00호 0-목)  ...     2017-11-10
# ..         ...                       ...  ...            ...         ...
# 877   착공후 60 일  지방계약법 (025조 01항 05호 0가목)  ...     2018-02-01
# 878   착공후 60 일  지방계약법 (025조 01항 05호 0가목)  ...     2018-02-01
# 879   착공후 60 일  지방계약법 (025조 01항 05호 0가목)  ...     2018-02-01
# 880   착공후 60 일  지방계약법 (025조 01항 05호 0가목)  ...     2018-02-01
# 881   착공후 60 일  지방계약법 (025조 01항 05호 0가목)  ...     2018-02-01
#
#     d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm d2bMngCnstwkNo  \
# 0
# 1
# 2
# 3
# 4
# ..                  ...              ...             ...            ...
# 877
# 878
# 879
# 880
# 881
#
#     pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm pubPrcrmntClsfcNo  \
# 0                   시설공사            시설물유지관리공사          72152402
# 1                   시설공사            시설물유지관리공사          72141119
# 2                   시설공사                 개별법령          72151597
# 3                   시설공사            시설물유지관리공사          72152799
# 4                   시설공사                 종합건설          72149001
# ..                   ...                  ...               ...
# 877                 시설공사            시설물유지관리공사          72152799
# 878                 시설공사            시설물유지관리공사          72152799
# 879                 시설공사            시설물유지관리공사          72152799
# 880                 시설공사            시설물유지관리공사          72152799
# 881                 시설공사            시설물유지관리공사          72152799
#
#     pubPrcrmntClsfcNm
# 0          금속구조물·창호공사
# 1            상하수도설비공사
# 2                전기공사
# 3            철근콘크리트공사
# 4                토목공사
# ..                ...
# 877          철근콘크리트공사
# 878          철근콘크리트공사
# 879          철근콘크리트공사
# 880          철근콘크리트공사
# 881          철근콘크리트공사
#
# [51831 rows x 47 columns]
# 계약현황에 대한 공사변경이력조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListCnstwkChgHstry?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDt=201712010000&inqryEndDt=201712312359&pageNo=7
# 8 page scraping start

# %% [markdown]
# ## 나) 인증키 관련 에러 시 타인증키로 수집

# %%
for each in ServiceKeyLst:
    if flag:
        print("수집완료")
        break
    for i in range(breakPoint, len(BASEPARAM_Lst)):
        if i == len(BASEPARAM_Lst) - 1:
            flag = True
        BASEPARAM_Lst[i]["ServiceKey"] = each
        try:
            resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
            print(resultDf)
            savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
        except Exception as e:
            print(e)
            breakPoint = i
            if e.args[0] == "22":
                print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            elif e.args[0] == "01":
                print("제공기관 서비스 제공 상태가 원활하지 않습니다.")
            else:
                print(e.args[0])
            break

# %%
print("종료 시점 파라미터키 : ",BASEPARAM_Lst[breakPoint])
print("수집 종료 : ", time.time()-starttime)

# %%
# #다중스레드 수집
# try:
#     starttime = time.time()
#     resultdfList = thread_crawl(BASEPARAM_Lst,URL,SITENAME,DATANAME,SERVICENAME,PAGEYN,scrapy)
#     print("time : ", time.time()-starttime)
# #오류 대비 원스레드 수집
# except Exception as e:
#     print(e)
#     print("multithread error, try onethread")
#     starttime = time.time()
#     resultdfList = []
#     for i in urlList:
#         try :
#             eachdata = getdata(i)
#         except :
#             continue
#         if eachdata is not None:
#             resultdfList.append(eachdata)
#     print("time : ", time.time()-starttime)
