# %% [markdown]
# # 1. 필요 라이브러리 선언

# %%
from datetime import datetime, timedelta
import pandas as pd
import requests
from lxml import html
from bs4 import BeautifulSoup 
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote
import os
import time
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %% [markdown]
# # 2. 함수 선언

# %%
### 함수정의: 시작일시(datetime 타입)를 입력 시 한달 후의 시작 및 종료일시를 반환하는 함수
### 파마리터정의:
###   - inDf: 시작일시 (예: datetime(2020,1,1))
def getAfterMonthDate(inDt):
    startYear = inDt.year
    startMonth = inDt.month
    endYear = inDt.year
    endMonth = inDt.month + 1
    if startMonth == 12:
        startYear += 1
        startMonth = 1
        endYear = startYear
        endMonth = startMonth + 1
    elif startMonth == 11:
        startMonth += 1
        endYear = startYear + 1
        endMonth = 1
    else:
        startMonth += 1
        endMonth = startMonth + 1
    outBgnDt = datetime(startYear, startMonth, inDt.day)
    outEndDt = datetime(endYear, endMonth, inDt.day) - timedelta(seconds=1)
    return outBgnDt, outEndDt

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
### 파마리터정의: 
###   - inurl: 메타정보의 "URL"컬럼값 (예: https://www.calspia.go.kr/io/openapi/cm/selectIoCmConstructionList.do )
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
###   - inParam: 메타정보의 "기본키 정보" (예: {'ServiceKey': 't1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g==','type':'json',...}")
###   - inPageYn: 메타정보의 "페이지 정보" (예: 페이지 파라미터 존재 시 1 값")
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수
def scrapy(inUrl, inSiteName, inDataName, inServiceName, inParam, inPageYn):
    emptyPd = pd.DataFrame()
    i=1
    while True:
        jsondata = pd.DataFrame()
        print("{} page scraping start".format(i))

        if(inPageYn==1):
            inParam["pageNo"] = i
        queryParams = '?' + urlencode(inParam)

        response = requests.get(inUrl+queryParams)
        
        time.sleep(0.1)
        
        print(inUrl+queryParams)
        response.encoding=STDENCODING
        
        if response.json()["response"]["body"]["totalCount"] == 0:
            print("데이터 없음")
            break

        try:
            jsondata = response.json()["response"]["body"]["items"]
        except Exception as e:
            if e.args[0] == 'Expecting value: line 1 column 1 (char 0)':
                xmlobj = BeautifulSoup(response.text,"lxml-xml")
                errorCode = xmlobj.find("returnReasonCode").text
                raise Exception(errorCode)

        if( jsondata == []):
            print("{} page is empty".format(i))
            break

        rowData = pd.DataFrame(jsondata)
#        print(rowData)
        emptyPd = emptyPd.append(rowData)

        if(inPageYn == 0):
            print("{} no pageNo".format(inPageYn))
            break
        i = i+1

    print("dataframe {} completed".format(inDataName))
    return emptyPd

# %%
### 함수정의: 데이터프레임을 Append 모드로 OUTPUT PATH에 저장하는 함수
### 파마리터정의:  (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
###   - inDf: 저장할 대상 데이터프레임
###   - inSiteName: 메타정보의 "자료대상" (예: 건설사업정보시스템)
###   - inDataName: 메타정보의 "자료명" (예: 공사정보 목록)
###   - inServiceName: 메타정보의 "서비스명" (예: getCntrctInfoListCnstwk)
def savedata(inDf, inSiteName, inDataName, inServiceName):
    # DATA SAVE TO THE OUTPUT PATH FOLDER
    outDir = os.path.join(OUTPUTPATH,inSiteName,inDataName)
    outFile = os.path.join( outDir, inServiceName) + ".csv"
    createFolder(outDir)
    if not os.path.exists(outFile):
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="w")
    else:
        inDf.to_csv(outFile, index=False, encoding="ms949", mode="a", header=False)
    print("{} save compled".format(inDataName) )

# %%
### 함수정의: 사이트 메타정보를 받아 데이터를 수집 후 수집결과를 반환하는 함수 (★★TBD 추후 HDFS경로 및 메타정보로 컬럼 추가 필요!!★★)
### 파마리터정의: 
###   - directory: outputpath 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

# %%
# def thread_crawl(paramList, inUrl, inSiteName, inDataName, inServiceName, inPageYn, fuction):
#     per_thread_num = 8
#     thread_list = []
#     result_list = []
#     with ThreadPoolExecutor(max_workers=per_thread_num) as exe:
#         for param in paramList:
#             fs = exe.submit(fuction,URL,SITENAME,DATANAME,SERVICENAME,param,PAGEYN)
#             thread_list.append(fs)
#         for execution in concurrent.futures.as_completed(thread_list):
#             df = execution.result()
#             result_list.append(df)
#     return result_list

# %% [markdown]
# # 3. 필요 변수 선언

# %% [markdown]
# ### 가) 메타데이터 업로드

# %%
metadata = pd.read_excel("../../input/datalake_meta22_new.xlsx", sheet_name="2. 조달청-조달정보개방포털", dtype={"순서":str, "비고":str})

# %% [markdown]
# ### 나) output 폴더 생성 변수

# %%
SITENAME = "조달청"

# %%
DATANAME= "나라장터검색조건에 의한 계약현황 용역조회"

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

# %%
SERVICENAME = targetData["서비스키"].values[0]

# %% [markdown]
# ### 다) 기본키 설정 (서비스별 변경 요)

# %% [markdown]
# #### 1) API KEY

# %%
initServiceKey = "t1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g=="

# %%
ServiceKeyLst = ["hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay+8Hgy660JdC9mVQCFhRKupVGwaw==",\
                 "Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x+MPLarA==",\
                "h2pHFUSHMnsx/wJfhd+fyC4L0X+g16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8/G+twwMfA9m8Q==",\
                "gDMXFxO2+zC7ZuEFiUXl+aWOrzfRGc7F52fIwOg5cdI92qRAnlOAAcL5qdsWx46zn5jMTFiMzG/0rQ/g/k2elw==",\
                "6wr0NwD9FgzjDWjNbT4iC0RBvs7vESA5VpmfNHZWE0BHguUn6YSLbh4FJ0FpMzLsEMtCiz3WxDYI5tcxCuPcPA=="]

# %% [markdown]
# #### 2) 조회 구분

# %%
inqryDiv = 1

# %% [markdown]
# #### 3) 등록일시 기준 조회 시작일자 및 종료일자

# %%
startYear, startMonth, startDay = 2012, 1, 1
bgnDt = datetime(startYear, startMonth, startDay)
endDt = datetime(startYear, startMonth + 1, startDay) - timedelta(seconds=1)

# %% [markdown]
# #### 4) 조회 rows 수

# %%
numOfRows = 999

# %% [markdown]
# #### 5) 기본키 딕셔너리 생성

# %%
BASEPARAM_KEY = targetData.기본키.values[0].split(",")

# %%
BASEPARAM_Lst = []

# %%
nowDt = datetime.now().strftime("%Y%m%d")

# %%
while True:
    inqryBgnDt = bgnDt.strftime("%Y%m%d")
    inqryEndDt = endDt.strftime("%Y%m%d")
    if inqryBgnDt > nowDt:
        break
    BASEPARAM = {}
    BASEPARAM_VAL = [numOfRows, initServiceKey, inqryDiv, inqryBgnDt, inqryEndDt]
    for i in range(len(BASEPARAM_VAL)):
        BASEPARAM[BASEPARAM_KEY[i]] = BASEPARAM_VAL[i]
        BASEPARAM["type"] = "json"
    BASEPARAM_Lst.append(BASEPARAM)    
    bgnDt, endDt = getAfterMonthDate(bgnDt)

# %% [markdown]
# ### 5) 함수 파라미터 설정

# %%
URL = targetData["URL"].values[0]

# %%
PAGEYN=1

# %%
STDENCODING='utf-8'

# %% [markdown]
# ### 6) OUTPUT 기본경로 설정

# %%
OUTPUTPATH="../../output"

# %% [markdown]
# # 4. 데이터 수집

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

# %%
filePath = os.path.join(OUTPUTPATH,SITENAME,DATANAME,SERVICENAME) + '.csv'

if os.path.isfile(filePath):
    os.remove(filePath)

# %%
breakPoint = 0

# %% [markdown]
# ## 가) 초기 인증키를 통한 수집

# %%
flag = False

# %%
starttime = time.time()
print("수집시작 : ", time.strftime('%c', time.localtime(time.time())))
for i in range(breakPoint, len(BASEPARAM_Lst)):
    try:
        resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
        print(resultDf)
        savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
    except Exception as e:
        breakPoint = i
        if e.args[0] == "22":
            print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            break
        else:
            print(e)
    if i == len(BASEPARAM_Lst) - 1:
        flag = True
# Out:
# 수집시작 :  Thu Apr 21 21:24:05 2022
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120101&inqryEndDate=20120131&pageNo=18
# 18 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 용역조회 completed
#       untyCntrctNo bsnsDivNm         dcsnCntrctNo          cntrctRefNo  \
# 0    2011120042202      일반용역          12118293600          12118293600
# 1    2011120047498      일반용역          22113315200          22113315200
# 2    2011120059136      일반용역          12118299100          12118299100
# 3    2011120076518      일반용역          24113116700          24113116700
# 4    2011120096395      일반용역          12118314100          12118314100
# ..             ...       ...                  ...                  ...
# 196  2012010036171      기술용역  ex20121131102100105  ex20121131102100105
# 197  2012010042386      기술용역  ex20121012402201001  ex20121012402201001
# 198  2012010045658      기술용역  ex20125001302100207  ex20125001302100207
# 199  2012010045107      기술용역        2012-000013-1        2012-000013-1
# 200  2012010040717      기술용역        2012-000011-1        2012-000011-1
#
#                            cntrctNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0      2012년도 영사콜센터 상담인력 위탁운영 업체 선정            N              신규
# 1                2012년도 승강기 유지관리 용역            N              신규
# 2         2012년도 KTV 외주프로그램 제작 사회분야            N              신규
# 3          광주교육대학교 종합학사행정시스템 유지보수용역            N              신규
# 4             2012년도 통일부 정보시스템 유지보수            N              신규
# ..                              ...          ...             ...
# 196          고속국도 제45호선외 4개소 기술자문용역            Y              신규
# 197       고속도로 휴게시설 임대료제도 개선방안 연구용역            Y              신규
# 198      호남지역본부 관내 사후환경영향조사 용역(제5차)            Y              신규
# 199                 2012년 본사사옥 청소용역            N              신규
# 200  (재공고) 대한지적공사 2012년도 교육교재 인쇄 납품            N              신규
#
#     cntrctCnclsDate cntrctPrd                 baseLawNm  ...  \
# 0        2012-01-01            국가계약법 (043조 00항 00호 0-목)  ...
# 1        2012-01-01            국가계약법 (026조 01항 05호 가-목)  ...
# 2        2012-01-01            국가계약법 (018조 03항 00호 0-목)  ...
# 3        2012-01-01  계약후 365일  국가계약법 (026조 01항 05호 가-목)  ...
# 4        2012-01-01            국가계약법 (021조 01항 08호 0-목)  ...
# ..              ...       ...                       ...  ...
# 196      2012-01-31                               국가계약법  ...
# 197      2012-01-31                               국가계약법  ...
# 198      2012-01-31                               국가계약법  ...
# 199      2012-01-31                               국가계약법  ...
# 200      2012-01-31                               국가계약법  ...
#
#           linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..                ...                 ...              ...             ...
# 196            한국도로공사
# 197            한국도로공사
# 198            한국도로공사
# 199  한국국토정보공사(대한지적공사)
# 200  한국국토정보공사(대한지적공사)
#
#     d2bMngDcsnNo d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..           ...            ...                  ...                  ...
# 196
# 197
# 198
# 199
# 200
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 196
# 197
# 198
# 199
# 200
#
# [16185 rows x 46 columns]
# 나라장터검색조건에 의한 계약현황 용역조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=29
# 30 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=30
# 31 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=31
# 32 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=32
# 33 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=33
# 34 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=34
# 35 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=35
# 36 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=36
# 37 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=37
# 38 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=38
# 39 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=39
# 40 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=40
# 41 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=41
# 42 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120201&inqryEndDate=20120229&pageNo=42
# 42 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 용역조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo       cntrctRefNo  \
# 0    2012010006040      일반용역    12128001400       12128001400
# 1    2012010016741      일반용역    22123005200       22123005200
# 2    2012010018723      일반용역    12128005800       12128005800
# 3    2012010022125      일반용역    12128006400       12128006400
# 4    2012010025888      일반용역    12128007900       12128007900
# ..             ...       ...            ...               ...
# 659  2012030027932      기술용역                 0000000000740800
# 660  2016010006638      기술용역  2012028529805     2012028529805
# 661  2017120080808      기술용역   용역-201200165   용역-201200165-08
# 662  2019020066603      기술용역   용역-201200165   용역-201200165-10
# 663  2019120299057      기술용역   용역-201200165   용역-201200165-11
#
#                                cntrctNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0          국군방송TV 중계및 위문열차공연 중계장비 사업자선정            N              신규
# 1                  2011년 정보시스템 통합유지보수용역            N              장기
# 2                  2012년도 전산장비 통합유지보수사업            N              신규
# 3                         2012년 CDN 서비스            N              신규
# 4                      2012년 118상담센터 운영            N              장기
# ..                                  ...          ...             ...
# 659  2012년도 화성지사 가스절연개폐기(GIS) 부분방전진단 용역            N              신규
# 660          목포시 환경에너지센터 건립사업 건설폐기물처리용역            N              신규
# 661          달산다목적댐 타당성조사 용역(2차년도/2012)            Y              장기
# 662          달산다목적댐 타당성조사 용역(2차년도/2012)            Y              장기
# 663          달산다목적댐 타당성조사 용역(2차년도/2012)            Y              장기
#
#     cntrctCnclsDate            cntrctPrd                 baseLawNm  ...  \
# 0        2012-02-01                       국가계약법 (043조 00항 00호 0-목)  ...
# 1        2012-02-01             20130131  지방계약법 (043조 01항 00호 0-목)  ...
# 2        2012-02-01                       국가계약법 (021조 01항 08호 0-목)  ...
# 3        2012-02-01  2012.2.1~2012.12.31  국가계약법 (043조 00항 00호 0-목)  ...
# 4        2012-02-01                       국가계약법 (043조 00항 00호 0-목)  ...
# ..              ...                  ...                       ...  ...
# 659      2012-02-29                                          국가계약법  ...
# 660      2012-02-29             착공후 90 일  지방계약법 (025조 01항 05호 0-목)  ...
# 661      2012-02-20                                                 ...
# 662      2012-02-20                                                 ...
# 663      2012-02-20                                                 ...
#
#     linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0
# 1
# 2
# 3
# 4
# ..          ...                 ...              ...             ...
# 659    한국지역난방공사
# 660
# 661     한국수자원공사
# 662     한국수자원공사
# 663     한국수자원공사
#
#     d2bMngDcsnNo d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..           ...            ...                  ...                  ...
# 659
# 660
# 661
# 662
# 663
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 659
# 660
# 661
# 662
# 663
#
# [40624 rows x 46 columns]
# 나라장터검색조건에 의한 계약현황 용역조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120301&inqryEndDate=20120331&pageNo=29
# 29 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 용역조회 completed
#       untyCntrctNo bsnsDivNm   dcsnCntrctNo    cntrctRefNo  \
# 0    2012020008130      일반용역    22123018000    22123018000
# 1    2012020057835      일반용역    12128027600    12128027600
# 2    2012020058891      일반용역    12128027700    12128027700
# 3    2012020062746      일반용역    33123005001    33123005001
# 4    2012020068536      일반용역    12128028800    12128028800
# ..             ...       ...            ...            ...
# 338  2016120128196      기술용역  2012036446802  2012036446802
# 339  2015040002830      기술용역  2012036496804  2012036496804
# 340  2015110065985      기술용역  2012035076302  2012035076302
# 341  2016090095880      기술용역  2012036546205  2012036546205
# 342  2016090011882      기술용역  2012036660501  2012036660501
#
#                                           cntrctNm cmmnCntrctYn  \
# 0                                   전자감응장치 유지보수 계약            N
# 1                        2012년도 법원대표전화안내센터 위탁 운영사업            N
# 2                                    2012년 기준 환자조사            N
# 3                              오송보건의료행정타운 안내도우미 용역            N
# 4                       2012년 국무총리실 국정관리시스템 외부위탁사업            N
# ..                                             ...          ...
# 338  지방도463호선 화지~고석정간 도로확포장공사 사후환경영향조사용역(전체 및 1차분)            N
# 339                         인천가족공원조성(2단계)사업 시공감리용역            Y
# 340     (구)한국환경자원공사 부가가치세 부과취소청구 행정소송 2심 및 상고 소송대리            N
# 341                      목천동∼송탄고가간 도로개설공사 GIS 구축용역            N
# 342               붕어섬 주변 생태공원 기본계획(변경) 및 실시설계용역-변경            N
#
#     lngtrmCtnuDivNm cntrctCnclsDate   cntrctPrd                 baseLawNm  \
# 0                신규      2012-03-01              국가계약법 (026조 01항 05호 가-목)
# 1                신규      2012-03-01              국가계약법 (043조 00항 00호 0-목)
# 2                신규      2012-03-01              국가계약법 (027조 01항 00호 0-목)
# 3                신규      2012-03-01              국가계약법 (010조 01항 00호 0-목)
# 4                신규      2012-03-01              국가계약법 (027조 01항 00호 0-목)
# ..              ...             ...         ...                       ...
# 338              장기      2012-03-30  착공후 2555 일  지방계약법 (012조 00항 00호 0-목)
# 339              신규      2012-03-30   착공후 840 일  지방계약법 (012조 00항 00호 0-목)
# 340              신규      2012-03-30   착공후 461 일  국가계약법 (010조 01항 00호 0-목)
# 341              장기      2012-03-30   착공후 420 일  지방계약법 (026조 01항 05호 가-목)
# 342              신규      2012-03-30   착공후 120 일  지방계약법 (020조 01항 06호 0-목)
#
#      ... linkInsttNm d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...         ...                 ...              ...             ...
# 338  ...
# 339  ...
# 340  ...
# 341  ...
# 342  ...
#
#     d2bMngDcsnNo d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..           ...            ...                  ...                  ...
# 338
# 339
# 340
# 341
# 342
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 338
# 339
# 340
# 341
# 342
#
# [27316 rows x 46 columns]
# 나라장터검색조건에 의한 계약현황 용역조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20120401&inqryEndDate=20120430&pageNo=21
# 22 page scraping start
# ...
# 4
# ..                ...               ...
# 277
# 278
# 279
# 280
# 281
#
# [56226 rows x 46 columns]
# 나라장터검색조건에 의한 계약현황 용역조회 save compled
# 1 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=1
# 2 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=2
# 3 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=3
# 4 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=4
# 5 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=5
# 6 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=6
# 7 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=7
# 8 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=8
# 9 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=9
# 10 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=10
# 11 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=11
# 12 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=12
# 13 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=13
# 14 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=14
# 15 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=15
# 16 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=16
# 17 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=17
# 18 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=18
# 19 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=19
# 20 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=20
# 21 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=21
# 22 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=22
# 23 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=23
# 24 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=24
# 25 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=25
# 26 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=26
# 27 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=27
# 28 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=28
# 29 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=29
# 30 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=30
# 31 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=31
# 32 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=32
# 33 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=33
# 34 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=34
# 35 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=35
# 36 page scraping start
# http://apis.data.go.kr/1230000/CntrctInfoService/getCntrctInfoListServcPPSSrch?numOfRows=999&type=json&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&inqryDiv=1&inqryBgnDate=20220401&inqryEndDate=20220430&pageNo=36
# 36 page is empty
# dataframe 나라장터검색조건에 의한 계약현황 용역조회 completed
#       untyCntrctNo bsnsDivNm dcsnCntrctNo  cntrctRefNo  \
# 0    2022030618132      일반용역  12228063500  12228063500
# 1    2022030594048      일반용역  12228061700  12228061700
# 2    2022030612973      일반용역  12228062300  12228062300
# 3    2022030505478      일반용역  00226063700  00226063700
# 4    2022030583027      일반용역  00228078500  00228078500
# ..             ...       ...          ...          ...
# 653    2022UMMA123      기술용역  2022UMMA123  2022UMMA123
# 654    2022HDK0090      기술용역  2022HDK0090  2022HDK0090
# 655    2022SFC0037      기술용역  2022SFC0037  2022SFC0037
# 656    2022UMM0322      기술용역  2022UMM0322  2022UMM0322
# 657    2022SCPA027      기술용역  2022SCPA027  2022SCPA027
#
#                                     cntrctNm cmmnCntrctYn lngtrmCtnuDivNm  \
# 0                  전지구 예보모델의 오차진단과 예측성 평가(Ⅲ)            Y              신규
# 1                          2022년도 표준국어대사전 개편            N              신규
# 2    2022년 공공외교 글로벌 디지털 커뮤니케이션 강화 및 인지도 제고사업            N              신규
# 3                    국립공원 CCTV 및 자동통제시설 유지관리            Y              신규
# 4                          2022년 글로벌 광고인재 육성            N              신규
# ..                                       ...          ...             ...
# 653              22-해-통합본관 신축등 2건 설계용역(C012)
# 654                         22년 기지 제초용역(POL)
# 655                     상륙돌격장갑차 3차 창정비 방안 연구
# 656              22-수상함 함정 설계/건조 기준 개정 연구 용역
# 657                22-0함대 00대대 00공장 등 지반조사용역
#
#     cntrctCnclsDate cntrctPrd                 baseLawNm  ... linkInsttNm  \
# 0        2022-04-01  20221130  국가계약법 (027조 01항 00호 0-목)  ...
# 1        2022-04-01  20221127  국가계약법 (027조 01항 00호 0-목)  ...
# 2        2022-04-01  20221231  국가계약법 (010조 01항 00호 0-목)  ...
# 3        2022-04-01  20230401  국가계약법 (021조 01항 08호 0-목)  ...
# 4        2022-04-01  20221231  국가계약법 (027조 01항 00호 0-목)  ...
# ..              ...       ...                       ...  ...         ...
# 653      2022-04-12                                      ...       방위사업청
# 654      2022-04-13                                      ...       방위사업청
# 655      2022-04-05                                      ...       방위사업청
# 656      2022-04-18                                      ...       방위사업청
# 657      2022-04-19                                      ...       방위사업청
#
#     d2bMngCntrctSttusNm d2bMngPrearngAmt d2bMngBidMthdNm d2bMngDcsnNo  \
# 0
# 1
# 2
# 3
# 4
# ..                  ...              ...             ...          ...
# 653
# 654
# 655
# 656
# 657
#
#     d2bMngCnstwkNo pubPrcrmntLrgClsfcNm pubPrcrmntMidClsfcNm  \
# 0
# 1
# 2
# 3
# 4
# ..             ...                  ...                  ...
# 653
# 654
# 655
# 656
# 657
#
#     pubPrcrmntClsfcNo pubPrcrmntClsfcNm
# 0
# 1
# 2
# 3
# 4
# ..                ...               ...
# 653
# 654
# 655
# 656
# 657
#
# [34624 rows x 46 columns]
# 나라장터검색조건에 의한 계약현황 용역조회 save compled

# %% [markdown]
# ## 나) 인증키 관련 에러 시 타인증키로 수집

# %%
for each in ServiceKeyLst:
    if flag:
        print("수집완료")
        break
    for i in range(breakPoint, len(BASEPARAM_Lst)):
        if i == len(BASEPARAM_Lst) - 1:
            flag = True
        BASEPARAM_Lst[i]["ServiceKey"] = each
        try:
            resultDf = scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[i],PAGEYN)
            print(resultDf)
            savedata(resultDf,SITENAME,DATANAME,SERVICENAME)
        except Exception as e:
            print(e)
            breakPoint = i
            if e.args[0] == "22":
                print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
            elif e.args[0] == "01":
                print("제공기관 서비스 제공 상태가 원활하지 않습니다.")
            else:
                print(e.args[0])
            break
# Out:
# 수집완료

# %%
print("종료 시점 파라미터키 : ",BASEPARAM_Lst[breakPoint])
print("수집 종료 : ", time.time()-starttime)
# Out:
# 종료 시점 파라미터키 :  {'numOfRows': 999, 'type': 'json', 'ServiceKey': 't1howSPLxqyKOseR6gxDm7IGYVVLGc+w3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn/baD6et/L6g==', 'inqryDiv': 1, 'inqryBgnDate': '20210301', 'inqryEndDate': '20210331', 'pageNo': 35}
# 수집 종료 :  30140.745716810226

# %%
# #다중스레드 수집
# try:
#     starttime = time.time()
#     resultdfList = thread_crawl(BASEPARAM_Lst,URL,SITENAME,DATANAME,SERVICENAME,PAGEYN,scrapy)
#     print("time : ", time.time()-starttime)
# #오류 대비 원스레드 수집
# except Exception as e:
#     print(e)
#     print("multithread error, try onethread")
#     starttime = time.time()
#     resultdfList = []
#     for i in urlList:
#         try :
#             eachdata = getdata(i)
#         except :
#             continue
#         if eachdata is not None:
#             resultdfList.append(eachdata)
#     print("time : ", time.time()-starttime)
