# %% [markdown]
# # 품질검사성적서 상세정보 현황

# %%
from common import commonFunc as cf
import pandas as pd
import pickle

pd.set_option('display.max_columns', None)
metadata = pd.read_excel("../input/datalake_meta22.xlsx")

SITENAME = "건설사업정보시스템"
DATANAME= "품질검사성적서 상세정보 현황"
with open("../input/calsapikey.pickle","rb") as fr:
    APIKEY = pickle.load(fr)

targetData = metadata.loc[metadata.자료명==DATANAME]
preSetFolder = targetData["저장폴더"].values[0]

preSetFolder
# Out:
# '../output/건설사업정보시스템/품질검사성적서 상세정보 현황/selectIoPmQtscView.csv'

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

##### 파라미터 설정 #####
URL = targetData["URL"].values[0]
SERVICENAME = targetData["서비스키"].values[0]
SERVICENAME = SERVICENAME.split(".")[0]
REQPARAM = targetData["요청변수"].values[0]
REQPARAM = REQPARAM.split(",")
PRIMARYKEY = targetData["기본키"].values[0]

# %%
JSONKEY = "detail1"
DUMMY = 0

# %%
# 페이지번호 설정
PAGEYN=1
if REQPARAM.count("pageNo") == 0:
    PAGEYN = 0
else:
    PAGEYN = 1
### 기본정보 설정 및 파라미터 설정 ###
PAGEYN
# Out:
# 0

# %%
#임시 
imsiDf = pd.read_csv(\
         "../output/건설사업정보시스템/품질검사성적서 등록 목록/selectIoPmQtscList.csv",low_memory=False, encoding="ms949")

# %%
dfCombi = imsiDf.loc[:,["tstrpcdseq"]].drop_duplicates()
dfCombi.reset_index(inplace=True, drop=True)
dfCombi
# Out:
#          tstrpcdseq
# 0       20180615097
# 1       20180607264
# 2       20180605977
# 3       20130908935
# 4       20130802416
# ...             ...
# 354155  20180413627
# 354156  20180413581
# 354157  20180413551
# 354158  20180413548
# 354159  20180413544
#
# [354160 rows x 1 columns]

# %%
newParam = dfCombi.tstrpcdseq.drop_duplicates().tolist()
len(newParam)
# Out:
# 354160

# %% [markdown]
# ## 파라미터정보 불러오기

# %%
orgParam = []
try:
    # 기존 데이터 및 파라미터 정보 불러오기
    # 리스트로 불러오기로 변경 0425
    orgParam = cf.loadparam(SITENAME,DATANAME,SERVICENAME)[0]
## 파일이 없는경우
except Exception as e:
    orgParam = []
    print(e)

ptlcmnoList = list( set(newParam) - set(orgParam) )
# 모드: 0=종료 1=append 2=새로생성
mode = 2

# 업데이트 할 내용이 없으면 종료
if ptlcmnoList == []:
    mode = 0
    print("{} 정보 quit모드 {} ".format(DATANAME, mode))
    quit()
# orgParam == []
elif orgParam == []:
    mode = 2
    print("{} 정보 new 모드 {} ".format(DATANAME, mode))
# 이외에는 append 모드
else:
    mode = 1
    print("{} 정보 append 모드 {} ".format(DATANAME, mode))

# len(ptlcmnoList)
# Out:
# [Errno 2] No such file or directory: '../output/건설사업정보시스템/품질검사성적서 상세정보 현황/selectIoPmQtscView.pickle'
# 품질검사성적서 상세정보 현황 정보 new 모드 2

# %%
resultDfMerged = pd.DataFrame()

# %%
numOfRows = 1000
resultDf = pd.DataFrame()
APICALL = 0 #추가

ptlcmnoListLen = len(ptlcmnoList)
pageList = [] #추가

for i in range(0,ptlcmnoListLen):
    BASEPARAM={"serviceKey":APIKEY[0], "tstRpcdSeq": ptlcmnoList[i], "type":"json"}
    print("BASEPARAM ",BASEPARAM)
    scrapyResult = cf.scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM,PAGEYN,APIKEY,APICALL, JSONKEY, DUMMY)
    resultDf = scrapyResult[0]
    pageList.append( scrapyResult[1] )
    APICALL = scrapyResult[2]
    if resultDf.empty: # 정상 데이터가 없는 경우
        print("No Data")
    else:
        resultDfMerged = resultDfMerged.append(resultDf)
# Out:
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201924, 'type': 'json'}
# 1 page scraping start apicall iter: 1 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201924, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201931, 'type': 'json'}
# 1 page scraping start apicall iter: 2 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201931, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201943, 'type': 'json'}
# 1 page scraping start apicall iter: 3 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201943, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407962, 'type': 'json'}
# 1 page scraping start apicall iter: 4 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407962, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201953, 'type': 'json'}
# 1 page scraping start apicall iter: 5 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201953, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201954, 'type': 'json'}
# 1 page scraping start apicall iter: 6 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201954, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201955, 'type': 'json'}
# 1 page scraping start apicall iter: 7 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201955, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407980, 'type': 'json'}
# 1 page scraping start apicall iter: 8 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407980, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407982, 'type': 'json'}
# 1 page scraping start apicall iter: 9 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20170407982, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407983, 'type': 'json'}
# 1 page scraping start apicall iter: 10 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407983, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407984, 'type': 'json'}
# 1 page scraping start apicall iter: 11 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20170407984, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407985, 'type': 'json'}
# 1 page scraping start apicall iter: 12 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170407985, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201969, 'type': 'json'}
# 1 page scraping start apicall iter: 13 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201969, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201971, 'type': 'json'}
# 1 page scraping start apicall iter: 14 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201971, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201978, 'type': 'json'}
# 1 page scraping start apicall iter: 15 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '49099D1D-E565-48E1-8A6F-D5F47135EA34', 'tstRpcdSeq': 20101201978, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201986, 'type': 'json'}
# 1 page scraping start apicall iter: 16 / used 0974320D-C689-4543-8464-10DE1E5505A9
# 0 no pageNo
# dataframe품질검사성적서 상세정보 현황, param:{'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20101201986, 'type': 'json'} rows: 28 completed
# BASEPARAM  {'serviceKey': '0974320D-C689-4543-8464-10DE1E5505A9', 'tstRpcdSeq': 20170408004, 'type': 'json'}
# 1 page scraping start apicall iter: 17 / used 49099D1D-E565-48E1-8A6F-D5F47135EA34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-656264e53aef> in <module>
#       9     BASEPARAM={"serviceKey":APIKEY[0], "tstRpcdSeq": ptlcmnoList[i], "type":"json"}
#      10     print("BASEPARAM ",BASEPARAM)
# ---> 11     scrapyResult = cf.scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM,PAGEYN,APIKEY,APICALL, JSONKEY, DUMMY)
#      12     resultDf = scrapyResult[0]
#      13     pageList.append( scrapyResult[1] )
#
# ~/Documents/GitHub/python_automation/apiScrapy/codeset/common/commonFunc.py in scrapy(inUrl, inSiteName, inDataName, inServiceName, inParam, inPageYn, inAPIKey, inApiCall, jsonkey, dummy, inType, prePageNo)
#      37
#      38             queryParams = '?' + urlencode(inParam)
# ---> 39             response = requests.get(inUrl+queryParams)
#      40             response.encoding=STDENCODING
#      41             rowData = pd.DataFrame()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# resultDfMerged = resultDfMerged.drop_duplicates()
resultDfMerged
# Out:
#     tstrpcdseq   rgsseq           mtlnm     tstbgdt     tsteddt      perno  \
# 0  20101201924  2007006      국제비파괴검사(주)  2010-11-29  2010-12-02  제2008-30호
# 0  20101201931  2008046        (주)시험과측량  2010-11-22  2010-11-29  제2011-20호
# 0  20101201943  2006011  (주)한국건설재료공학연구소  2010-11-17  2010-11-26   제2008-6호
# 0  20170407962  2014048    (주)한국건설시험연구소  2017-04-12  2017-04-17    경남-4-1호
# 0  20101201953  2006011  (주)한국건설재료공학연구소  2010-11-18  2010-11-29   제2008-6호
# 0       대구옥포 보금자리 주택지구 조성사업          None                     풍림산업(주)
# 0  서울지하철 9호선 2단계 915공구 건설공사  서울시 도시기반시설본부               경남기업㈜,대원건설산업㈜
# 0        육군종합행정학교 이전사업 시설공사          None  현대건설(주),(주)동양고속건설,한진중공업(주)
# 0   부전~마산 복선전철 민간투자시설사업 1공구      스마트레일(주)                     SK건설(주)
# 0   부전~마산 복선전철 민간투자시설사업 1공구      스마트레일(주)                     SK건설(주)
# 0          장항국가생태산업단지 1-2공구      한국토지주택공사                     강산건설(주)
# 0   부전~마산 복선전철 민간투자시설사업 1공구      스마트레일(주)                     SK건설(주)
# 0   부전~마산 복선전철 민간투자시설사업 1공구      스마트레일(주)                     SK건설(주)
# 0      북전주 IC 진입로 확장공사 지반조사            공란                          공란
# 0      북전주 IC 진입로 확장공사 지반조사            공란                          공란
# 0                        공란            공란                          공란
# 0         의성초등학교~법원간도로확포장공사          의성군수                   대림종합건설(주)
#
#            clntnm                  clntadr      altsitnm smorsecd  smorsecdnm  \
# 0             조재윤      서울시 송파구 풍납동 388-1번지          인장강도     None        None
# 0           이 선 우    경기도 양평군 용문면 마룡리 207번지        압축강도 외     None        None
# 0           이 행 용                     None         함수비 외     None        None
# 0             최연준                     None        액소성,입도        G  기타 건설자재ㆍ부재
# 0           김 문 환                     None          함수비외     None        None
# 0           김 상 길      서울시 강남구 논현동 231-5번지        인장강도 외     None        None
# 0           좌 태 훈                     None           치수외     None        None
# 0           박 경 돌                     None  용해 실리카량 : Sc        G  기타 건설자재ㆍ부재
# 0           박 경 돌                     None           입 도        G  기타 건설자재ㆍ부재
# 0             안경호                     None         원강성 외        G  기타 건설자재ㆍ부재
# 0           박 경 돌                     None           입 도        G  기타 건설자재ㆍ부재
# 0           박 경 돌                     None           입 도        G  기타 건설자재ㆍ부재
# 0  (주)지우엔지니어링 이승욱  전주시 덕진구 송천동 2가 571-15번지       입도 외 7건     None        None
# 0  (주)지우엔지니어링 이승욱  전주시 덕진구 송천동 2가 571-15번지       입도 외 7건     None        None
# 0  (주)지우엔지니어링 이승욱  전주시 덕진구 송천동 2가 571-15번지       입도 외 7건     None        None
# 0            의성군수        경북 의성군 의성읍 군청길 31          압축강도     None        None
#
#        stwrdt    ccwxpcdt clntblnornm clntchrbsnnm          fctnm tstct  \
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0  2010-06-14  2018-08-31   현대산업개발(주)         None           None  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0  2014-06-27  2020-06-26     SK건설(주)         None  군사시설(OO부대 본청)  None
# 0  2014-06-27  2020-06-26     SK건설(주)         None  군사시설(OO부대 본청)  None
# 0  2014-09-03  2018-06-20     강산건설(주)         None           None  None
# 0  2014-06-27  2020-06-26     SK건설(주)         None  군사시설(OO부대 본청)  None
# 0  2014-06-27  2020-06-26     SK건설(주)         None  군사시설(OO부대 본청)  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
# 0          --          --        None         None           None  None
#
#   coieyn  index
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0
# 0      N      0

# %%
cf.savedata(resultDfMerged, SITENAME,DATANAME,SERVICENAME,mode)
# Out:
# 품질검사성적서 상세정보 현황 save compled

# %%
resultDfMerged.shape
# Out:
# (16, 28)

# %%
# 기존사용된 파라미터 정보에 추가 파라미터 append 후 저장
ptlcmnoList = orgParam + ptlcmnoList

paramList = [ptlcmnoList,pageList]
# 최종 파라미터 저장
cf.saveparam(paramList, SITENAME,DATANAME,SERVICENAME)
