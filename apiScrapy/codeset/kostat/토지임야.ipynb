# %%
#!/usr/bin/env python
# coding: utf-8

# ## 1. 필요 라이브러리 선언

# In[1]:


import os
import sys
os.chdir('C:/Users/luthe/Desktop/python_automation-master/apiScrapy/codeset/kostat')
# os.chdir('/data/KITECH/apiScrapy/codeset/kostat/')
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname("./"))))
from common import commonFunc as cf
import pandas as pd
import pickle
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
import time
import psycopg2
from sqlalchemy import create_engine
import gc
# from concurrent.futures import ThreadPoolExecutor
# import concurrent.futures

# %%
# ## 2. 필요 변수 선언

# ### 2-1. 메타데이터 업로드
metadata = pd.read_excel("../../input/datalake_meta22.xlsx", sheet_name="3. 통계청",engine="openpyxl")

# ### 2-2. output 폴더 생성 변수
SITENAME = "kostat"
DATANAME= "토지임야목록조회"
targetData = metadata.loc[metadata.자료명==DATANAME]
SERVICENAME = targetData["서비스키"].values[0].split(".")[0]

org_data = pd.DataFrame()
try:
    # 기존 데이터 및 파라미터 정보 불러오기
    org_data = cf.loadparam(SITENAME,DATANAME,SERVICENAME)
## 파일이 없는경우
except Exception as e:
    print(e)

tot_cnt = 0

# ### 2-3. 기본키 설정
# ##i# 1) API KEY
with open("../../input/ppsapikey.pickle","rb") as fr:
        ServiceKeyLst = pickle.load(fr)

pnuDf = pd.read_csv("./행정구역코드(법정동코드).csv", encoding="ms949")
pnuList = pnuDf.loc[pnuDf.폐지여부 == "존재"].법정동코드.values.tolist()

numOfRows = "999"

BASEPARAM_KEY = targetData.기본키.values[0].split(",")
BASEPARAM_Lst = []
BASEPARAM_VAL = [numOfRows]

for i in range(len(pnuList)):
    BASEPARAM = {}
    BASEPARAM_VAL.append(pnuList[i])
    for j in range(len(BASEPARAM_VAL)):
        BASEPARAM[BASEPARAM_KEY[j]] = BASEPARAM_VAL[j]
    BASEPARAM_Lst.append(BASEPARAM)
    BASEPARAM_VAL.pop()


# ### 2-4. 함수 파라미터
URL = targetData["URL"].values[0]
PAGEYN=1
STDENCODING='utf-8'
APICALL=0
inType = "xml"
jsonkey = "ladfrlVOList"
# Out:
# [Errno 2] No such file or directory: '../output\\kostat\\토지임야목록조회.pickle'

# %%
# ## 3. 데이터 수집
# ### 3-2. 데이터 수집
# # 4. 데이터 수집
breakPoint = 0
# ## 가) 초기 인증키를 통한 수집
flag = False
pageList = []
dfList = []
failList = []

starttime = time.time()
print("수집시작 : ", time.strftime('%c', time.localtime(time.time())))
for i in range(len(ServiceKeyLst)):
    if flag:
        break
    while (breakPoint < len(BASEPARAM_Lst)):
        if breakPoint == len(BASEPARAM_Lst) - 1:
            flag = True
        try:
            BASEPARAM_Lst[breakPoint]["ServiceKey"] = ServiceKeyLst[i]
            scrapyResult = cf.scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM_Lst[breakPoint],PAGEYN,ServiceKeyLst,APICALL, jsonkey=jsonkey,inType=inType)
            resultDf = scrapyResult[0]
            if resultDf is None:
                failList.append(BASEPARAM_Lst[breakPoint])
                if breakPoint <= len(BASEPARAM_Lst) - 1:
                    breakPoint=breakPoint+1
                continue
            elif type(resultDf) == pd.core.frame.DataFrame:
                # print(resultDf)
                if resultDf.empty:
                    failList.append(BASEPARAM_Lst[breakPoint])
                    if breakPoint <= len(BASEPARAM_Lst) - 1:
                        breakPoint=breakPoint+1
                    continue
            dfList.append(resultDf)
            print(dfList)
            pageList.append(scrapyResult[1])
            APICALL = scrapyResult[2]
            tot_cnt = tot_cnt + scrapyResult[3]

        except Exception as e:
            print(e)
            if e.args[0] == "22" or e.args[0] == "20":
                print("LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR")
                break
            else:
                time.sleep(10)
        else:
            if breakPoint <= len(BASEPARAM_Lst) - 1:
                breakPoint=breakPoint+1

# finalResultDf = pd.concat(dfList).reset_index(drop=True)
# Out:
# 수집시작 :  Wed Jun 15 09:45:05 2022
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1100000000&ServiceKey=t1howSPLxqyKOseR6gxDm7IGYVVLGc%2Bw3wF7N4e9ufwr2g9sttHbYCQTR4dBbiVc16v1tnmTEkn%2FbaD6et%2FL6g%3D%3D&pageNo=1
# 20
# 20
# LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1100000000&ServiceKey=hMw9eN6ZYKvMWUUvEykxVelOH07uAKhQYzFMUV5r4QpvdYgJehQANKE5bay%2B8Hgy660JdC9mVQCFhRKupVGwaw%3D%3D&pageNo=1
# 20
# 20
# LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1100000000&ServiceKey=Yc4hy9aka4aSXaZzlPFTem6eM79Fm4r2PPJXGxxYxlZVUhXWeYkFbodwmpsXrkEhqUzKYoq7hFyfx3x%2BMPLarA%3D%3D&pageNo=1
# 20
# 20
# LIMITED_NUMBER_OF_SERVICE_REQUESTS_EXCEEDS_ERROR
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1100000000&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# No Data
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111000000&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# No Data
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010100&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010100&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010200&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010200&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010200100010001  1111010200  서울특별시 종로구 신교동      1-1            1
# 1    1111010200100010004  1111010200  서울특별시 종로구 신교동      1-4            1
# 2    1111010200100010007  1111010200  서울특별시 종로구 신교동      1-7            1
# 3    1111010200100010008  1111010200  서울특별시 종로구 신교동      1-8            1
# 4    1111010200100010009  1111010200  서울특별시 종로구 신교동      1-9            1
# ..                   ...         ...            ...      ...          ...
# 390  1111010200100820002  1111010200  서울특별시 종로구 신교동     82-2            1
# 391  1111010200100820003  1111010200  서울특별시 종로구 신교동     82-3            1
# 392  1111010200100820004  1111010200  서울특별시 종로구 신교동     82-4            1
# 393  1111010200100820005  1111010200  서울특별시 종로구 신교동     82-5            1
# 394  1111010200100820006  1111010200  서울특별시 종로구 신교동     82-6            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         10         학교용지  27057.9           02
# 1             토지대장         10         학교용지  10183.9           02
# 2             토지대장         08            대     54.5           02
# 3             토지대장         08            대    152.1           05
# 4             토지대장         08            대      9.6           02
# ..             ...        ...          ...      ...          ...
# 390           토지대장         14           도로     12.9           05
# 391           토지대장         08            대     60.3           01
# 392           토지대장         08            대        1           01
# 393           토지대장         14           도로      5.7           01
# 394           토지대장         08            대     11.8           01
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              국유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3              군유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 390            군유지         0        06       1:600  2022-06-07
# 391             개인         0        06       1:600  2022-06-07
# 392             개인         0        06       1:600  2022-06-07
# 393             개인         0        06       1:600  2022-06-07
# 394             개인         0        06       1:600  2022-06-07
#
# [395 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010300&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010300&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010200100010001  1111010200  서울특별시 종로구 신교동      1-1            1
# 1    1111010200100010004  1111010200  서울특별시 종로구 신교동      1-4            1
# 2    1111010200100010007  1111010200  서울특별시 종로구 신교동      1-7            1
# 3    1111010200100010008  1111010200  서울특별시 종로구 신교동      1-8            1
# 4    1111010200100010009  1111010200  서울특별시 종로구 신교동      1-9            1
# ..                   ...         ...            ...      ...          ...
# 390  1111010200100820002  1111010200  서울특별시 종로구 신교동     82-2            1
# 391  1111010200100820003  1111010200  서울특별시 종로구 신교동     82-3            1
# 392  1111010200100820004  1111010200  서울특별시 종로구 신교동     82-4            1
# 393  1111010200100820005  1111010200  서울특별시 종로구 신교동     82-5            1
# 394  1111010200100820006  1111010200  서울특별시 종로구 신교동     82-6            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         10         학교용지  27057.9           02
# 1             토지대장         10         학교용지  10183.9           02
# 2             토지대장         08            대     54.5           02
# 3             토지대장         08            대    152.1           05
# 4             토지대장         08            대      9.6           02
# ..             ...        ...          ...      ...          ...
# 390           토지대장         14           도로     12.9           05
# 391           토지대장         08            대     60.3           01
# 392           토지대장         08            대        1           01
# 393           토지대장         14           도로      5.7           01
# 394           토지대장         08            대     11.8           01
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              국유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3              군유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 390            군유지         0        06       1:600  2022-06-07
# 391             개인         0        06       1:600  2022-06-07
# 392             개인         0        06       1:600  2022-06-07
# 393             개인         0        06       1:600  2022-06-07
# 394             개인         0        06       1:600  2022-06-07
#
# [395 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111010300100010001  1111010300  서울특별시 종로구 궁정동      1-1            1
# 1   1111010300100010002  1111010300  서울특별시 종로구 궁정동      1-2            1
# 2   1111010300100010004  1111010300  서울특별시 종로구 궁정동      1-4            1
# 3   1111010300100010030  1111010300  서울특별시 종로구 궁정동     1-30            1
# 4   1111010300100010045  1111010300  서울특별시 종로구 궁정동     1-45            1
# ..                  ...         ...            ...      ...          ...
# 95  1111010300100980002  1111010300  서울특별시 종로구 궁정동     98-2            1
# 96  1111010300100980003  1111010300  서울특별시 종로구 궁정동     98-3            1
# 97  1111010300100980008  1111010300  서울특별시 종로구 궁정동     98-8            1
# 98  1111010300100980009  1111010300  서울특별시 종로구 궁정동     98-9            1
# 99  1111010300100980010  1111010300  서울특별시 종로구 궁정동    98-10            1
#
#    regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0            토지대장         26          사적지    17667           02
# 1            토지대장         08            대   9857.4           02
# 2            토지대장         26          사적지      9.3           02
# 3            토지대장         14           도로   2197.3           02
# 4            토지대장         08            대   2612.9           02
# ..            ...        ...          ...      ...          ...
# 95           토지대장         14           도로   1649.6           02
# 96           토지대장         08            대    105.8           02
# 97           토지대장         14           도로     99.2           04
# 98           토지대장         14           도로    118.2           04
# 99           토지대장         14           도로   2940.3           04
#
#    posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0             국유지         0        06       1:600  2022-06-07
# 1             국유지         0        06       1:600  2022-06-07
# 2             국유지         0        06       1:600  2022-06-07
# 3             국유지         0        06       1:600  2022-06-07
# 4             국유지         0        06       1:600  2022-06-07
# ..            ...       ...       ...         ...         ...
# 95            국유지         0        06       1:600  2022-06-07
# 96            국유지         0        06       1:600  2022-06-07
# 97         시, 도유지         0        06       1:600  2022-06-07
# 98         시, 도유지         0        06       1:600  2022-06-07
# 99         시, 도유지         0        06       1:600  2022-06-07
#
# [100 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010400&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010400&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010200100010001  1111010200  서울특별시 종로구 신교동      1-1            1
# 1    1111010200100010004  1111010200  서울특별시 종로구 신교동      1-4            1
# 2    1111010200100010007  1111010200  서울특별시 종로구 신교동      1-7            1
# 3    1111010200100010008  1111010200  서울특별시 종로구 신교동      1-8            1
# 4    1111010200100010009  1111010200  서울특별시 종로구 신교동      1-9            1
# ..                   ...         ...            ...      ...          ...
# 390  1111010200100820002  1111010200  서울특별시 종로구 신교동     82-2            1
# 391  1111010200100820003  1111010200  서울특별시 종로구 신교동     82-3            1
# 392  1111010200100820004  1111010200  서울특별시 종로구 신교동     82-4            1
# 393  1111010200100820005  1111010200  서울특별시 종로구 신교동     82-5            1
# 394  1111010200100820006  1111010200  서울특별시 종로구 신교동     82-6            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         10         학교용지  27057.9           02
# 1             토지대장         10         학교용지  10183.9           02
# 2             토지대장         08            대     54.5           02
# 3             토지대장         08            대    152.1           05
# 4             토지대장         08            대      9.6           02
# ..             ...        ...          ...      ...          ...
# 390           토지대장         14           도로     12.9           05
# 391           토지대장         08            대     60.3           01
# 392           토지대장         08            대        1           01
# 393           토지대장         14           도로      5.7           01
# 394           토지대장         08            대     11.8           01
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              국유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3              군유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 390            군유지         0        06       1:600  2022-06-07
# 391             개인         0        06       1:600  2022-06-07
# 392             개인         0        06       1:600  2022-06-07
# 393             개인         0        06       1:600  2022-06-07
# 394             개인         0        06       1:600  2022-06-07
#
# [395 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111010300100010001  1111010300  서울특별시 종로구 궁정동      1-1            1
# 1   1111010300100010002  1111010300  서울특별시 종로구 궁정동      1-2            1
# 2   1111010300100010004  1111010300  서울특별시 종로구 궁정동      1-4            1
# 3   1111010300100010030  1111010300  서울특별시 종로구 궁정동     1-30            1
# 4   1111010300100010045  1111010300  서울특별시 종로구 궁정동     1-45            1
# ..                  ...         ...            ...      ...          ...
# 95  1111010300100980002  1111010300  서울특별시 종로구 궁정동     98-2            1
# 96  1111010300100980003  1111010300  서울특별시 종로구 궁정동     98-3            1
# 97  1111010300100980008  1111010300  서울특별시 종로구 궁정동     98-8            1
# 98  1111010300100980009  1111010300  서울특별시 종로구 궁정동     98-9            1
# 99  1111010300100980010  1111010300  서울특별시 종로구 궁정동    98-10            1
#
#    regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0            토지대장         26          사적지    17667           02
# 1            토지대장         08            대   9857.4           02
# 2            토지대장         26          사적지      9.3           02
# 3            토지대장         14           도로   2197.3           02
# 4            토지대장         08            대   2612.9           02
# ..            ...        ...          ...      ...          ...
# 95           토지대장         14           도로   1649.6           02
# 96           토지대장         08            대    105.8           02
# 97           토지대장         14           도로     99.2           04
# 98           토지대장         14           도로    118.2           04
# 99           토지대장         14           도로   2940.3           04
#
#    posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0             국유지         0        06       1:600  2022-06-07
# 1             국유지         0        06       1:600  2022-06-07
# 2             국유지         0        06       1:600  2022-06-07
# 3             국유지         0        06       1:600  2022-06-07
# 4             국유지         0        06       1:600  2022-06-07
# ..            ...       ...       ...         ...         ...
# 95            국유지         0        06       1:600  2022-06-07
# 96            국유지         0        06       1:600  2022-06-07
# 97         시, 도유지         0        06       1:600  2022-06-07
# 98         시, 도유지         0        06       1:600  2022-06-07
# 99         시, 도유지         0        06       1:600  2022-06-07
#
# [100 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010400100040001  1111010400  서울특별시 종로구 효자동      4-1            1
# 1    1111010400100040002  1111010400  서울특별시 종로구 효자동      4-2            1
# 2    1111010400100070002  1111010400  서울특별시 종로구 효자동      7-2            1
# 3    1111010400100080000  1111010400  서울특별시 종로구 효자동      8-0            1
# 4    1111010400100150001  1111010400  서울특별시 종로구 효자동     15-1            1
# ..                   ...         ...            ...      ...          ...
# 284  1111010400101960000  1111010400  서울특별시 종로구 효자동    196-0            1
# 285  1111010400101960002  1111010400  서울특별시 종로구 효자동    196-2            1
# 286  1111010400101960007  1111010400  서울특별시 종로구 효자동    196-7            1
# 287  1111010400101960008  1111010400  서울특별시 종로구 효자동    196-8            1
# 288  1111010400102000000  1111010400  서울특별시 종로구 효자동    200-0            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         14           도로     11.9           02
# 1             토지대장         17           하천    429.8           05
# 2             토지대장         14           도로      6.6           02
# 3             토지대장         14           도로   5665.3           04
# 4             토지대장         18           구거    525.6           05
# ..             ...        ...          ...      ...          ...
# 284           토지대장         08            대    918.2           02
# 285           토지대장         08            대    383.5           01
# 286           토지대장         08            대   1211.2           02
# 287           토지대장         08            대      116           02
# 288           토지대장         08            대    101.4           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              군유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3           시, 도유지         0        06       1:600  2022-06-07
# 4              군유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 284            국유지         0        06       1:600  2022-06-07
# 285             개인         0        06       1:600  2022-06-07
# 286            국유지         0        06       1:600  2022-06-07
# 287            국유지         0        06       1:600  2022-06-07
# 288            국유지         0        06       1:600  2022-06-07
#
# [289 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010500&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010500&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010200100010001  1111010200  서울특별시 종로구 신교동      1-1            1
# 1    1111010200100010004  1111010200  서울특별시 종로구 신교동      1-4            1
# 2    1111010200100010007  1111010200  서울특별시 종로구 신교동      1-7            1
# 3    1111010200100010008  1111010200  서울특별시 종로구 신교동      1-8            1
# 4    1111010200100010009  1111010200  서울특별시 종로구 신교동      1-9            1
# ..                   ...         ...            ...      ...          ...
# 390  1111010200100820002  1111010200  서울특별시 종로구 신교동     82-2            1
# 391  1111010200100820003  1111010200  서울특별시 종로구 신교동     82-3            1
# 392  1111010200100820004  1111010200  서울특별시 종로구 신교동     82-4            1
# 393  1111010200100820005  1111010200  서울특별시 종로구 신교동     82-5            1
# 394  1111010200100820006  1111010200  서울특별시 종로구 신교동     82-6            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         10         학교용지  27057.9           02
# 1             토지대장         10         학교용지  10183.9           02
# 2             토지대장         08            대     54.5           02
# 3             토지대장         08            대    152.1           05
# 4             토지대장         08            대      9.6           02
# ..             ...        ...          ...      ...          ...
# 390           토지대장         14           도로     12.9           05
# 391           토지대장         08            대     60.3           01
# 392           토지대장         08            대        1           01
# 393           토지대장         14           도로      5.7           01
# 394           토지대장         08            대     11.8           01
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              국유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3              군유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 390            군유지         0        06       1:600  2022-06-07
# 391             개인         0        06       1:600  2022-06-07
# 392             개인         0        06       1:600  2022-06-07
# 393             개인         0        06       1:600  2022-06-07
# 394             개인         0        06       1:600  2022-06-07
#
# [395 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111010300100010001  1111010300  서울특별시 종로구 궁정동      1-1            1
# 1   1111010300100010002  1111010300  서울특별시 종로구 궁정동      1-2            1
# 2   1111010300100010004  1111010300  서울특별시 종로구 궁정동      1-4            1
# 3   1111010300100010030  1111010300  서울특별시 종로구 궁정동     1-30            1
# 4   1111010300100010045  1111010300  서울특별시 종로구 궁정동     1-45            1
# ..                  ...         ...            ...      ...          ...
# 95  1111010300100980002  1111010300  서울특별시 종로구 궁정동     98-2            1
# 96  1111010300100980003  1111010300  서울특별시 종로구 궁정동     98-3            1
# 97  1111010300100980008  1111010300  서울특별시 종로구 궁정동     98-8            1
# 98  1111010300100980009  1111010300  서울특별시 종로구 궁정동     98-9            1
# 99  1111010300100980010  1111010300  서울특별시 종로구 궁정동    98-10            1
#
#    regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0            토지대장         26          사적지    17667           02
# 1            토지대장         08            대   9857.4           02
# 2            토지대장         26          사적지      9.3           02
# 3            토지대장         14           도로   2197.3           02
# 4            토지대장         08            대   2612.9           02
# ..            ...        ...          ...      ...          ...
# 95           토지대장         14           도로   1649.6           02
# 96           토지대장         08            대    105.8           02
# 97           토지대장         14           도로     99.2           04
# 98           토지대장         14           도로    118.2           04
# 99           토지대장         14           도로   2940.3           04
#
#    posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0             국유지         0        06       1:600  2022-06-07
# 1             국유지         0        06       1:600  2022-06-07
# 2             국유지         0        06       1:600  2022-06-07
# 3             국유지         0        06       1:600  2022-06-07
# 4             국유지         0        06       1:600  2022-06-07
# ..            ...       ...       ...         ...         ...
# 95            국유지         0        06       1:600  2022-06-07
# 96            국유지         0        06       1:600  2022-06-07
# 97         시, 도유지         0        06       1:600  2022-06-07
# 98         시, 도유지         0        06       1:600  2022-06-07
# 99         시, 도유지         0        06       1:600  2022-06-07
#
# [100 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010400100040001  1111010400  서울특별시 종로구 효자동      4-1            1
# 1    1111010400100040002  1111010400  서울특별시 종로구 효자동      4-2            1
# 2    1111010400100070002  1111010400  서울특별시 종로구 효자동      7-2            1
# 3    1111010400100080000  1111010400  서울특별시 종로구 효자동      8-0            1
# 4    1111010400100150001  1111010400  서울특별시 종로구 효자동     15-1            1
# ..                   ...         ...            ...      ...          ...
# 284  1111010400101960000  1111010400  서울특별시 종로구 효자동    196-0            1
# 285  1111010400101960002  1111010400  서울특별시 종로구 효자동    196-2            1
# 286  1111010400101960007  1111010400  서울특별시 종로구 효자동    196-7            1
# 287  1111010400101960008  1111010400  서울특별시 종로구 효자동    196-8            1
# 288  1111010400102000000  1111010400  서울특별시 종로구 효자동    200-0            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         14           도로     11.9           02
# 1             토지대장         17           하천    429.8           05
# 2             토지대장         14           도로      6.6           02
# 3             토지대장         14           도로   5665.3           04
# 4             토지대장         18           구거    525.6           05
# ..             ...        ...          ...      ...          ...
# 284           토지대장         08            대    918.2           02
# 285           토지대장         08            대    383.5           01
# 286           토지대장         08            대   1211.2           02
# 287           토지대장         08            대      116           02
# 288           토지대장         08            대    101.4           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              군유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3           시, 도유지         0        06       1:600  2022-06-07
# 4              군유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 284            국유지         0        06       1:600  2022-06-07
# 285             개인         0        06       1:600  2022-06-07
# 286            국유지         0        06       1:600  2022-06-07
# 287            국유지         0        06       1:600  2022-06-07
# 288            국유지         0        06       1:600  2022-06-07
#
# [289 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010500100060000  1111010500  서울특별시 종로구 창성동      6-0            1
# 1    1111010500100070001  1111010500  서울특별시 종로구 창성동      7-1            1
# 2    1111010500100070002  1111010500  서울특별시 종로구 창성동      7-2            1
# 3    1111010500100090002  1111010500  서울특별시 종로구 창성동      9-2            1
# 4    1111010500100130000  1111010500  서울특별시 종로구 창성동     13-0            1
# ..                   ...         ...            ...      ...          ...
# 262  1111010500101620002  1111010500  서울특별시 종로구 창성동    162-2            1
# 263  1111010500101630000  1111010500  서울특별시 종로구 창성동    163-0            1
# 264  1111010500101700003  1111010500  서울특별시 종로구 창성동    170-3            1
# 265  1111010500101830001  1111010500  서울특별시 종로구 창성동    183-1            1
# 266  1111010500101830002  1111010500  서울특별시 종로구 창성동    183-2            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         14           도로    357.9           02
# 1             토지대장         14           도로     73.3           04
# 2             토지대장         14           도로     35.8           04
# 3             토지대장         14           도로      5.6           02
# 4             토지대장         14           도로    453.5           02
# ..             ...        ...          ...      ...          ...
# 262           토지대장         14           도로      6.6           02
# 263           토지대장         14           도로   4936.1           04
# 264           토지대장         18           구거        5           05
# 265           토지대장         14           도로     72.8           02
# 266           토지대장         18           구거    320.7           05
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1           시, 도유지         0        06       1:600  2022-06-07
# 2           시, 도유지         0        06       1:600  2022-06-07
# 3              국유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 262            국유지         0        06       1:600  2022-06-07
# 263         시, 도유지         0        06       1:600  2022-06-07
# 264            군유지         0        06       1:600  2022-06-07
# 265            국유지         0        06       1:600  2022-06-07
# 266            군유지         0        06       1:600  2022-06-07
#
# [267 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010600&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111010600&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data
# [                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010100100010000  1111010100  서울특별시 종로구 청운동      1-0            1
# 1    1111010100100010001  1111010100  서울특별시 종로구 청운동      1-1            1
# 2    1111010100100010002  1111010100  서울특별시 종로구 청운동      1-2            1
# 3    1111010100100010003  1111010100  서울특별시 종로구 청운동      1-3            1
# 4    1111010100100010004  1111010100  서울특별시 종로구 청운동      1-4            1
# ..                   ...         ...            ...      ...          ...
# 814  1111010100200080006  1111010100  서울특별시 종로구 청운동      8-6            2
# 815  1111010100200080008  1111010100  서울특별시 종로구 청운동      8-8            2
# 816  1111010100200090004  1111010100  서울특별시 종로구 청운동      9-4            2
# 817  1111010100200100003  1111010100  서울특별시 종로구 청운동     10-3            2
# 818  1111010100200150000  1111010100  서울특별시 종로구 청운동     15-0            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대  15622.1           01
# 1             토지대장         14           도로     21.4           04
# 2             토지대장         08            대     20.7           01
# 3             토지대장         08            대     24.4           01
# 4             토지대장         14           도로     48.9           04
# ..             ...        ...          ...      ...          ...
# 814           임야대장         05           임야       17           06
# 815           임야대장         05           임야      383           06
# 816           임야대장         05           임야     4321           06
# 817           임야대장         05           임야      410           01
# 818           임야대장         14           도로      965           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         0        00          수치  2022-06-07
# 1           시, 도유지         0        00          수치  2022-06-07
# 2               개인         0        00          수치  2022-06-07
# 3               개인         0        00          수치  2022-06-07
# 4           시, 도유지         0        00          수치  2022-06-07
# ..             ...       ...       ...         ...         ...
# 814             법인         0        30      1:3000  2022-06-07
# 815             법인         0        30      1:3000  2022-06-07
# 816             법인         0        30      1:3000  2022-06-07
# 817             개인         0        30      1:3000  2022-06-07
# 818            국유지         0        30      1:3000  2022-06-07
#
# [819 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111010200100010001  1111010200  서울특별시 종로구 신교동      1-1            1
# 1    1111010200100010004  1111010200  서울특별시 종로구 신교동      1-4            1
# 2    1111010200100010007  1111010200  서울특별시 종로구 신교동      1-7            1
# 3    1111010200100010008  1111010200  서울특별시 종로구 신교동      1-8            1
# 4    1111010200100010009  1111010200  서울특별시 종로구 신교동      1-9            1
# ..                   ...         ...            ...      ...          ...
# 390  1111010200100820002  1111010200  서울특별시 종로구 신교동     82-2            1
# 391  1111010200100820003  1111010200  서울특별시 종로구 신교동     82-3            1
# 392  1111010200100820004  1111010200  서울특별시 종로구 신교동     82-4            1
# 393  1111010200100820005  1111010200  서울특별시 종로구 신교동     82-5            1
# 394  1111010200100820006  1111010200  서울특별시 종로구 신교동     82-6            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         10         학교용지  27057.9           02
# 1             토지대장         10         학교용지  10183.9           02
# 2             토지대장         08            대     54.5           02
# 3             토지대장         08            대    152.1           05
# 4             토지대장         08            대      9.6           02
# ..             ...        ...          ...      ...          ...
# 390           토지대장         14           도로     12.9           05
# 391           토지대장         08            대     60.3           01
# 392           토지대장         08            대        1           01
# 393           토지대장         14           도로      5.7           01
# 394           토지대장         08            대     11.8           01
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1              국유지         0        06       1:600  2022-06-07
# 2              국유지         0        06       1:600  2022-06-07
# 3              군유지         0        06       1:600  2022-06-07
# 4              국유지         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 390            군유지         0        06       1:600  2022-06-07
# 391             개인         0        06       1:600  2022-06-07
# 392             개인         0        06       1:600  2022-06-07
# 393             개인         0        06       1:600  2022-06-07
# 394             개인         0        06       1:600  2022-06-07
#
# [395 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111010300100010001  1111010300  서울특별시 종로구 궁정동      1-1            1
# 1   1111010300100010002  1111010300  서울특별시 종로구 궁정동      1-2            1
# 2   1111010300100010004  1111010300  서울특별시 종로구 궁정동      1-4            1
# 3   1111010300100010030  1111010300  서울특별시 종로구 궁정동     1-30            1
# 4   1111010300100010045  1111010300  서울특별시 종로구 궁정동     1-45            1
# ..                  ...         ...            ...      ...          ...
# 95  1111010300100980002  1111010300  서울특별시 종로구 궁정동     98-2            1
# 96  1111010300100980003  1111010300  서울특별시 종로구 궁정동     98-3            1
# 97  1111010300100980008  1111010300  서울특별시 종로구 궁정동     98-8            1
# ...
# 385             개인         0        06       1:600  2022-06-07
# 386            국유지         0        06       1:600  2022-06-07
# 387             개인         0        06       1:600  2022-06-07
# 388             개인         0        06       1:600  2022-06-07
#
# [389 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111011300100100003  1111011300  서울특별시 종로구 필운동     10-3            1
# 1    1111011300100120000  1111011300  서울특별시 종로구 필운동     12-0            1
# 2    1111011300100120007  1111011300  서울특별시 종로구 필운동     12-7            1
# 3    1111011300100130001  1111011300  서울특별시 종로구 필운동     13-1            1
# 4    1111011300100130002  1111011300  서울특별시 종로구 필운동     13-2            1
# ..                   ...         ...            ...      ...          ...
# 396  1111011300200010006  1111011300  서울특별시 종로구 필운동      1-6            2
# 397  1111011300200010007  1111011300  서울특별시 종로구 필운동      1-7            2
# 398  1111011300200010008  1111011300  서울특별시 종로구 필운동      1-8            2
# 399  1111011300200010009  1111011300  서울특별시 종로구 필운동      1-9            2
# 400  1111011300200010010  1111011300  서울특별시 종로구 필운동     1-10            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         18           구거     33.6           05
# 1             토지대장         10         학교용지  12558.4           06
# 2             토지대장         10         학교용지     85.4           01
# 3             토지대장         08            대     16.5           01
# 4             토지대장         08            대     39.7           01
# ..             ...        ...          ...      ...          ...
# 396           임야대장         05           임야       21           01
# 397           임야대장         05           임야       27           01
# 398           임야대장         05           임야       17           01
# 399           임야대장         05           임야       10           01
# 400           임야대장         05           임야       93           06
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              군유지         0        06       1:600  2022-06-07
# 1               법인         0        06       1:600  2022-06-07
# 2               개인         0        06       1:600  2022-06-07
# 3               개인         0        06       1:600  2022-06-07
# 4               개인         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 396             개인         0        30      1:3000  2022-06-07
# 397             개인         0        30      1:3000  2022-06-07
# 398             개인         0        30      1:3000  2022-06-07
# 399             개인         2        30      1:3000  2022-06-07
# 400             법인         0        30      1:3000  2022-06-07
#
# [401 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111011400100010001  1111011400  서울특별시 종로구 내자동      1-1            1
# 1    1111011400100010002  1111011400  서울특별시 종로구 내자동      1-2            1
# 2    1111011400100010003  1111011400  서울특별시 종로구 내자동      1-3            1
# 3    1111011400100010004  1111011400  서울특별시 종로구 내자동      1-4            1
# 4    1111011400100010005  1111011400  서울특별시 종로구 내자동      1-5            1
# ..                   ...         ...            ...      ...          ...
# 236  1111011400102380000  1111011400  서울특별시 종로구 내자동    238-0            1
# 237  1111011400102380001  1111011400  서울특별시 종로구 내자동    238-1            1
# 238  1111011400102380002  1111011400  서울특별시 종로구 내자동    238-2            1
# 239  1111011400102380003  1111011400  서울특별시 종로구 내자동    238-3            1
# 240  1111011400102380004  1111011400  서울특별시 종로구 내자동    238-4            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         14           도로   1734.6           05
# 1             토지대장         08            대      119           01
# 2             토지대장         08            대      187           01
# 3             토지대장         08            대      2.7           03
# 4             토지대장         08            대       .3           03
# ..             ...        ...          ...      ...          ...
# 236           토지대장         14           도로     15.4           04
# 237           토지대장         14           도로    170.2           04
# 238           토지대장         14           도로       65           04
# 239           토지대장         14           도로     53.4           04
# 240           토지대장         14           도로     72.8           04
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              군유지         0        06       1:600  2022-06-07
# 1               개인         2        06       1:600  2022-06-07
# 2               개인         0        06       1:600  2022-06-07
# 3      외국인, 외국공공기관         1        06       1:600  2022-06-07
# 4      외국인, 외국공공기관         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 236         시, 도유지         0        00          수치  2022-06-07
# 237         시, 도유지         0        00          수치  2022-06-07
# 238         시, 도유지         0        00          수치  2022-06-07
# 239         시, 도유지         0        00          수치  2022-06-07
# 240         시, 도유지         0        00          수치  2022-06-07
#
# [241 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111011500100010001  1111011500  서울특별시 종로구 사직동      1-1            1
# 1    1111011500100010002  1111011500  서울특별시 종로구 사직동      1-2            1
# 2    1111011500100010003  1111011500  서울특별시 종로구 사직동      1-3            1
# 3    1111011500100010006  1111011500  서울특별시 종로구 사직동      1-6            1
# 4    1111011500100010007  1111011500  서울특별시 종로구 사직동      1-7            1
# ..                   ...         ...            ...      ...          ...
# 595  1111011500200010039  1111011500  서울특별시 종로구 사직동     1-39            2
# 596  1111011500200010040  1111011500  서울특별시 종로구 사직동     1-40            2
# 597  1111011500200010042  1111011500  서울특별시 종로구 사직동     1-42            2
# 598  1111011500200010045  1111011500  서울특별시 종로구 사직동     1-45            2
# 599  1111011500200010054  1111011500  서울특별시 종로구 사직동     1-54            2
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         14           도로   3695.9           02
# 1             토지대장         10         학교용지   3510.7           04
# 2             토지대장         08            대      357           01
# 3             토지대장         08            대     33.1           01
# 4             토지대장         08            대     64.8           01
# ..             ...        ...          ...      ...          ...
# 595           임야대장         05           임야     6767           02
# 596           임야대장         05           임야       83           02
# 597           임야대장         05           임야       26           02
# 598           임야대장         05           임야     3134           02
# 599           임야대장         14           도로      214           02
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0              국유지         0        06       1:600  2022-06-07
# 1           시, 도유지         0        06       1:600  2022-06-07
# 2               개인         0        06       1:600  2022-06-07
# 3               개인         1        06       1:600  2022-06-07
# 4               개인         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 595            국유지         0        30      1:3000  2022-06-07
# 596            국유지         0        30      1:3000  2022-06-07
# 597            국유지         0        30      1:3000  2022-06-07
# 598            국유지         0        30      1:3000  2022-06-07
# 599            국유지         0        30      1:3000  2022-06-07
#
# [600 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111011600100170001  1111011600  서울특별시 종로구 도렴동     17-1            1
# 1   1111011600100240001  1111011600  서울특별시 종로구 도렴동     24-1            1
# 2   1111011600100240002  1111011600  서울특별시 종로구 도렴동     24-2            1
# 3   1111011600100250001  1111011600  서울특별시 종로구 도렴동     25-1            1
# 4   1111011600100260001  1111011600  서울특별시 종로구 도렴동     26-1            1
# ..                  ...         ...            ...      ...          ...
# 74  1111011600101500007  1111011600  서울특별시 종로구 도렴동    150-7            1
# 75  1111011600101500008  1111011600  서울특별시 종로구 도렴동    150-8            1
# 76  1111011600101500010  1111011600  서울특별시 종로구 도렴동   150-10            1
# 77  1111011600101500012  1111011600  서울특별시 종로구 도렴동   150-12            1
# 78  1111011600101500013  1111011600  서울특별시 종로구 도렴동   150-13            1
#
#    regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0            토지대장         14           도로     19.8           02
# 1            토지대장         14           도로      6.6           02
# 2            토지대장         08            대      1.8           01
# 3            토지대장         14           도로        2           02
# 4            토지대장         14           도로        1           02
# ..            ...        ...          ...      ...          ...
# 74           토지대장         08            대    106.8           01
# 75           토지대장         08            대     54.9           01
# 76           토지대장         08            대      1.3           06
# 77           토지대장         08            대       .7           01
# 78           토지대장         08            대      1.3           04
#
#    posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0             국유지         0        06       1:600  2022-06-07
# 1             국유지         0        06       1:600  2022-06-07
# 2              개인         0        06       1:600  2022-06-07
# 3             국유지         0        06       1:600  2022-06-07
# 4             국유지         0        06       1:600  2022-06-07
# ..            ...       ...       ...         ...         ...
# 74             개인         0        06       1:600  2022-06-07
# 75             개인         1        06       1:600  2022-06-07
# 76             법인         0        06       1:600  2022-06-07
# 77             개인         1        06       1:600  2022-06-07
# 78         시, 도유지         0        06       1:600  2022-06-07
#
# [79 rows x 15 columns],                      pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0    1111011700100010000  1111011700  서울특별시 종로구 당주동      1-0            1
# 1    1111011700100010001  1111011700  서울특별시 종로구 당주동      1-1            1
# 2    1111011700100020002  1111011700  서울특별시 종로구 당주동      2-2            1
# 3    1111011700100020003  1111011700  서울특별시 종로구 당주동      2-3            1
# 4    1111011700100030001  1111011700  서울특별시 종로구 당주동      3-1            1
# ..                   ...         ...            ...      ...          ...
# 182  1111011700101720001  1111011700  서울특별시 종로구 당주동    172-1            1
# 183  1111011700101720002  1111011700  서울특별시 종로구 당주동    172-2            1
# 184  1111011700101720003  1111011700  서울특별시 종로구 당주동    172-3            1
# 185  1111011700101720004  1111011700  서울특별시 종로구 당주동    172-4            1
# 186  1111011700101720005  1111011700  서울특별시 종로구 당주동    172-5            1
#
#     regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0             토지대장         08            대    219.5           01
# 1             토지대장         14           도로    723.8           05
# 2             토지대장         08            대    217.1           01
# 3             토지대장         08            대    110.4           01
# 4             토지대장         08            대     87.6           06
# ..             ...        ...          ...      ...          ...
# 182           토지대장         25         종교용지      7.1           08
# 183           토지대장         22           공원    255.4           05
# 184           토지대장         14           도로       .2           05
# 185           토지대장         14           도로     53.2           05
# 186           토지대장         11          주차장      2.4           05
#
#     posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0               개인         1        06       1:600  2022-06-07
# 1              군유지         0        06       1:600  2022-06-07
# 2               개인         0        06       1:600  2022-06-07
# 3               개인         0        06       1:600  2022-06-07
# 4               법인         0        06       1:600  2022-06-07
# ..             ...       ...       ...         ...         ...
# 182           종교단체         0        00          수치  2022-06-07
# 183            군유지         0        00          수치  2022-06-07
# 184            군유지         0        00          수치  2022-06-07
# 185            군유지         0        00          수치  2022-06-07
# 186            군유지         0        00          수치  2022-06-07
#
# [187 rows x 15 columns],                     pnu      ldCode       ldCodeNm mnnmSlno regstrSeCode  \
# 0   1111011800100010000  1111011800  서울특별시 종로구 내수동      1-0            1
# 1   1111011800100030000  1111011800  서울특별시 종로구 내수동      3-0            1
# 2   1111011800100030001  1111011800  서울특별시 종로구 내수동      3-1            1
# 3   1111011800100040000  1111011800  서울특별시 종로구 내수동      4-0            1
# 4   1111011800100040001  1111011800  서울특별시 종로구 내수동      4-1            1
# ..                  ...         ...            ...      ...          ...
# 91  1111011800102100001  1111011800  서울특별시 종로구 내수동    210-1            1
# 92  1111011800102100002  1111011800  서울특별시 종로구 내수동    210-2            1
# 93  1111011800102120001  1111011800  서울특별시 종로구 내수동    212-1            1
# 94  1111011800102120002  1111011800  서울특별시 종로구 내수동    212-2            1
# 95  1111011800102150001  1111011800  서울특별시 종로구 내수동    215-1            1
#
#    regstrSeCodeNm lndcgrCode lndcgrCodeNm lndpclAr posesnSeCode  \
# 0            토지대장         08            대    763.7           03
# 1            토지대장         08            대    257.9           01
# 2            토지대장         18           구거    571.9           05
# 3            토지대장         08            대    264.5           01
# 4            토지대장         14           도로    101.9           05
# ..            ...        ...          ...      ...          ...
# 91           토지대장         14           도로     62.5           04
# 92           토지대장         14           도로     71.5           04
# 93           토지대장         14           도로     13.7           04
# 94           토지대장         14           도로     37.8           05
# 95           토지대장         14           도로     54.6           04
#
#    posesnSeCodeNm cnrsPsnCo ladFrtlSc ladFrtlScNm  lastUpdtDt
# 0     외국인, 외국공공기관         0        06       1:600  2022-06-07
# 1              개인         1        06       1:600  2022-06-07
# 2             군유지         0        06       1:600  2022-06-07
# 3              개인         7        06       1:600  2022-06-07
# 4             군유지         0        06       1:600  2022-06-07
# ..            ...       ...       ...         ...         ...
# 91         시, 도유지         0        00          수치  2022-06-07
# 92         시, 도유지         0        00          수치  2022-06-07
# 93         시, 도유지         0        00          수치  2022-06-07
# 94            군유지         0        00          수치  2022-06-07
# 95         시, 도유지         0        00          수치  2022-06-07
#
# [96 rows x 15 columns]]
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111011900&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=1
# http://apis.data.go.kr/1611000/nsdi/eios/LadfrlService/ladfrlList.xml?numOfRows=999&pnu=1111011900&ServiceKey=h2pHFUSHMnsx%2FwJfhd%2BfyC4L0X%2Bg16L0FhJvDcos8Px4Fqttih1HONUkKXQ5ITmYlq1vjIYT8%2FG%2BtwwMfA9m8Q%3D%3D&pageNo=2
# No Data

# %%
data_exist = True
try:
    finalResultDf = pd.concat(dfList).reset_index(drop=True)
except:
    finalResultDf = pd.DataFrame()
    data_exist = False


completed = False
data_chg_cnt = len(finalResultDf)

if tot_cnt == data_chg_cnt or (tot_cnt != data_chg_cnt and len(failList) == 0):
    completed = True
    print("수집 종료 : ", time.time()-starttime)
else:
    print("수집 실패 : ", time.time()-starttime)

if completed:
    exit_date = datetime.now().strftime("%Y%m%d")

    typical_col = ['ctgry_cd', 'ctgry_nm', 'phase_cd', 'phase_nm', 'lifecycle_cd',
           'lifecycle_nm', 'clnt_cd', 'clnt_nm', 'biz_regst_num', 'cntrct_frm_nm',
           'domain_cd', 'domain_nm', 'facility_cd', 'facility_nm',
           'cnstrct_wrk_cd', 'cnstrct_wrk_nm', 'wbslv1_cd', 'wbslv1_nm',
           'wbslv2_cd', 'wbslv2_nm', 'authrt_lv_cd', 'authrt_lv_nm', 'reg_ymd',
           'end_ymd', 'strg_dir', 'strg_filename', 'data_src', 'ntwrk',
           'clct_mthd', 'clmn_nm_hanguel', 'clmn_nm', 'preprcs', 'updt_cycle',
           'req_url', 'svc_key', 'base_key', 'req_param', 'data_type']

    dtype = {}

    for each in typical_col:
        dtype[each] = str

    clc_typcial = pd.read_csv("../../../input/meta/clc_typical.csv", names=typical_col, dtype=dtype)

    index = clc_typcial[(clc_typcial.ctgry_nm == "통계청") & (clc_typcial.strg_filename == f'{DATANAME}.csv')].index.values[0]
    clc_typcial.loc[index,"reg_ymd"] = exit_date

    clc_typcial.to_csv("../../../input/meta/clc_typical.csv", encoding="utf8",index=False,header=False)

    update_query = "update experdba.prov_data set reg_ymd = '{0}' where ctgry_nm = '통계청' and strg_filename = '{1}.csv'".format(exit_date, DATANAME)

    try:
        #  conn = psycopg2.connect(database="postgres",user="postgres",password="kopo",host="localhost",port="5432")
        conn = psycopg2.connect(database="experdb", user="experdb", password="experdb", host="172.16.0.153",
                                port="5432")
        cur = conn.cursor()

        cur.execute(update_query)
        #   cur.execute(del_query)
        conn.commit()
        print("execute success")
    except Exeception as e:
        print("database connection error")
        print(e)
    finally:
        if conn:
            conn.close()

# %%
# # 6. 적재를 위한 테이블 가공 및 적재

# In[36]:

data_tot_cnt = 0
if completed and data_exist:
    columnNm = targetData.한글컬럼명.values[0].split(",")

    finalResultDf.columns = columnNm

    mergedDf = pd.DataFrame()

    if not org_data.empty:
        mergedDf = pd.concat([org_data, finalResultDf])
    else:
        mergedDf = pd.concat([org_data, finalResultDf])

    del org_data
    del finalResultDf
    gc.collect()

    mergedDf.reset_index(drop=True, inplace=True)

    cf.savedata(mergedDf, SITENAME, DATANAME, SERVICENAME)
    cf.saveparam(mergedDf, SITENAME, DATANAME, SERVICENAME)

    data_tot_cnt = len(mergedDf)

end_time = time.time()



try:
    engine = create_engine("postgresql://experdb:experdb@172.16.0.153:5432/experdb", encoding='utf8')

    conn_engine = engine.connect()

    if completed:
        exec_df = pd.DataFrame([{"site_name": SITENAME, "pg_name": DATANAME, "data_upt_cnt": data_chg_cnt,
                                 "data_tot_cnt": data_tot_cnt,
                                 "exec_date": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d"),
                                 "start_time": datetime.fromtimestamp(starttime).strftime("%Y-%m-%d %H:%M:%S"),
                                 "end_time": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d %H:%M:%S"),
                                 "exec_time": time.strftime('%H:%M:%S', time.gmtime(end_time - starttime)),
                                 "exec_yn": 'Y'}])
    else:
        exec_df = pd.DataFrame([{"site_name": SITENAME, "pg_name": DATANAME, "data_upt_cnt": data_chg_cnt,
                                 "data_tot_cnt": data_tot_cnt,
                                 "exec_date": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d"),
                                 "start_time": datetime.fromtimestamp(starttime).strftime("%Y-%m-%d %H:%M:%S"),
                                 "end_time": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d %H:%M:%S"),
                                 "exec_time": time.strftime('%H:%M:%S', time.gmtime(end_time - starttime)),
                                 "exec_yn": 'N'}])
    exec_df.to_sql("prov_stat", engine, if_exists="append", index=False)
except Exception as e:
    print(e)
else:
    conn_engine.close()








# try:
#     engine = create_engine("postgresql://experdb:experdb@172.16.0.153:5432/experdb", encoding='utf8')
#
#     conn_engine = engine.connect()
#
#     if completed:
#         exec_df = pd.DataFrame([{"site_name": SITENAME, "pg_name": DATANAME, "data_upt_cnt": data_chg_cnt,
#                                  "data_tot_cnt": data_tot_cnt,
#                                  "exec_date": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d"),
#                                  "start_time": datetime.fromtimestamp(starttime).strftime("%Y-%m-%d %H:%M:%S"),
#                                  "end_time": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d %H:%M:%S"),
#                                  "exec_time": time.strftime('%H:%M:%S', time.gmtime(end_time - starttime)),
#                                  "exec_yn": 'Y'}])
#     else:
#         exec_df = pd.DataFrame([{"site_name": SITENAME, "pg_name": DATANAME, "data_upt_cnt": data_chg_cnt,
#                                  "data_tot_cnt": data_tot_cnt,
#                                  "exec_date": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d"),
#                                  "start_time": datetime.fromtimestamp(starttime).strftime("%Y-%m-%d %H:%M:%S"),
#                                  "end_time": datetime.fromtimestamp(end_time).strftime("%Y-%m-%d %H:%M:%S"),
#                                  "exec_time": time.strftime('%H:%M:%S', time.gmtime(end_time - starttime)),
#                                  "exec_yn": 'N'}])
#     exec_df.to_sql("prov_stat", engine, if_exists="append", index=False)
# except Exception as e:
#     print(e)
# else:
#     conn_engine.close()
