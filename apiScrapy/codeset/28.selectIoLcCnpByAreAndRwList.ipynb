# %% [markdown]
# # 공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황

# %%
from common import commonFunc as cf
import pandas as pd
pd.set_option('display.max_columns', None)
metadata = pd.read_excel("../input/datalake_meta22.xlsx")

SITENAME = "건설사업정보시스템"
DATANAME= "공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황"
APIKEY = "1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF"

targetData = metadata.loc[metadata.자료명==DATANAME]
preSetFolder = targetData["저장폴더"].values[0]

preSetFolder
# Out:
# '../output/건설사업정보시스템/공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황/selectIoLcCnpByAreAndRwList.csv'

# %%
targetData = metadata.loc[metadata.자료명==DATANAME]

##### 파라미터 설정 #####
URL = targetData["URL"].values[0]
SERVICENAME = targetData["서비스키"].values[0]
SERVICENAME = SERVICENAME.split(".")[0]
REQPARAM = targetData["요청변수"].values[0]
REQPARAM = REQPARAM.split(",")
PRIMARYKEY = targetData["기본키"].values[0]

# %%
JSONKEY = "items"
DUMMY = 0

# %%
#### 페이지번호 설정 ###
PAGEYN=1
if REQPARAM.count("pageyn") == 0:
    PAGEYN = 0
else:
    PAGEYN = 1

# %%
resultDfMerged = pd.DataFrame()

# %%
import datetime

currentDateTime = datetime.datetime.now()
date = currentDateTime.date()
endYr = date.strftime("%Y")
endYr
# Out:
# '2022'

# %%
# 기준년도 산정
# 2007년 부터 데이터 존재하나, 1990년부터 수행
startYr = "1990"
dateRange = list(map(int,pd.period_range(startYr,endYr,freq='Y').strftime('%Y').tolist()))
# dateRange

# %%
resultDf = pd.DataFrame()
for i  in dateRange:
    print(i)
    BASEPARAM={"serviceKey":APIKEY,"searchSrYr1": str(i), "searchSrYr2": str(i-1), "searchSrYr3": str(i-2),"type":"json"}
    resultDf = cf.scrapy(URL,SITENAME,DATANAME,SERVICENAME,BASEPARAM,PAGEYN, JSONKEY, DUMMY)
    if resultDf.empty: # 정상 데이터가 없는 경우
            print("No Data")
    else:
        resultDfMerged = resultDfMerged.append(resultDf)
# Out:
# 1990
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1990', 'searchSrYr2': '1989', 'searchSrYr3': '1988', 'type': 'json'} rows: 0 completed
# No Data
# 1991
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1991', 'searchSrYr2': '1990', 'searchSrYr3': '1989', 'type': 'json'} rows: 0 completed
# No Data
# 1992
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1992', 'searchSrYr2': '1991', 'searchSrYr3': '1990', 'type': 'json'} rows: 0 completed
# No Data
# 1993
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1993', 'searchSrYr2': '1992', 'searchSrYr3': '1991', 'type': 'json'} rows: 0 completed
# No Data
# 1994
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1994', 'searchSrYr2': '1993', 'searchSrYr3': '1992', 'type': 'json'} rows: 0 completed
# No Data
# 1995
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1995', 'searchSrYr2': '1994', 'searchSrYr3': '1993', 'type': 'json'} rows: 0 completed
# No Data
# 1996
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1996', 'searchSrYr2': '1995', 'searchSrYr3': '1994', 'type': 'json'} rows: 0 completed
# No Data
# 1997
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1997', 'searchSrYr2': '1996', 'searchSrYr3': '1995', 'type': 'json'} rows: 0 completed
# No Data
# 1998
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1998', 'searchSrYr2': '1997', 'searchSrYr3': '1996', 'type': 'json'} rows: 0 completed
# No Data
# 1999
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '1999', 'searchSrYr2': '1998', 'searchSrYr3': '1997', 'type': 'json'} rows: 0 completed
# No Data
# 2000
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2000', 'searchSrYr2': '1999', 'searchSrYr3': '1998', 'type': 'json'} rows: 0 completed
# No Data
# 2001
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2001', 'searchSrYr2': '2000', 'searchSrYr3': '1999', 'type': 'json'} rows: 0 completed
# No Data
# 2002
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2002', 'searchSrYr2': '2001', 'searchSrYr3': '2000', 'type': 'json'} rows: 0 completed
# No Data
# 2003
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2003', 'searchSrYr2': '2002', 'searchSrYr3': '2001', 'type': 'json'} rows: 0 completed
# No Data
# 2004
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2004', 'searchSrYr2': '2003', 'searchSrYr3': '2002', 'type': 'json'} rows: 0 completed
# No Data
# 2005
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2005', 'searchSrYr2': '2004', 'searchSrYr3': '2003', 'type': 'json'} rows: 0 completed
# No Data
# 2006
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 1 page is empty
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2006', 'searchSrYr2': '2005', 'searchSrYr3': '2004', 'type': 'json'} rows: 0 completed
# No Data
# 2007
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2007', 'searchSrYr2': '2006', 'searchSrYr3': '2005', 'type': 'json'} rows: 22 completed
# 2008
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2008', 'searchSrYr2': '2007', 'searchSrYr3': '2006', 'type': 'json'} rows: 22 completed
# 2009
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2009', 'searchSrYr2': '2008', 'searchSrYr3': '2007', 'type': 'json'} rows: 22 completed
# 2010
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2010', 'searchSrYr2': '2009', 'searchSrYr3': '2008', 'type': 'json'} rows: 22 completed
# 2011
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2011', 'searchSrYr2': '2010', 'searchSrYr3': '2009', 'type': 'json'} rows: 22 completed
# 2012
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2012', 'searchSrYr2': '2011', 'searchSrYr3': '2010', 'type': 'json'} rows: 22 completed
# 2013
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2013', 'searchSrYr2': '2012', 'searchSrYr3': '2011', 'type': 'json'} rows: 22 completed
# 2014
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2014', 'searchSrYr2': '2013', 'searchSrYr3': '2012', 'type': 'json'} rows: 22 completed
# 2015
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2015', 'searchSrYr2': '2014', 'searchSrYr3': '2013', 'type': 'json'} rows: 22 completed
# 2016
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2016', 'searchSrYr2': '2015', 'searchSrYr3': '2014', 'type': 'json'} rows: 22 completed
# 2017
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2017', 'searchSrYr2': '2016', 'searchSrYr3': '2015', 'type': 'json'} rows: 22 completed
# 2018
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2018', 'searchSrYr2': '2017', 'searchSrYr3': '2016', 'type': 'json'} rows: 22 completed
# 2019
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2019', 'searchSrYr2': '2018', 'searchSrYr3': '2017', 'type': 'json'} rows: 22 completed
# 2020
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2020', 'searchSrYr2': '2019', 'searchSrYr3': '2018', 'type': 'json'} rows: 22 completed
# 2021
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2021', 'searchSrYr2': '2020', 'searchSrYr3': '2019', 'type': 'json'} rows: 22 completed
# 2022
# 1 page scraping start
# Empty DataFrame
# Columns: []
# Index: []
# 0 no pageNo
# dataframe공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황, param:{'serviceKey': '1EFCBE0D-3203-4485-A7BA-5F5DB2B476BF', 'searchSrYr1': '2022', 'searchSrYr2': '2021', 'searchSrYr3': '2020', 'type': 'json'} rows: 22 completed

# %%
resultDfMerged
# Out:
#    cmndtlcdnm                  tojiamt1               tojiamt2  \
# 0         강원도     451,227,581,370(2.02)                0(0.00)
# 1         경기도  9,202,335,466,881(41.14)                0(0.00)
# 2         경남도     604,141,703,714(2.70)                0(0.00)
# 3         경북도     574,172,774,664(2.57)                0(0.00)
# 4         광주시     269,266,244,769(1.20)                0(0.00)
# ..        ...                       ...                    ...
# 12        전남도                   0(0.00)   52,720,195,100(0.46)
# 13        전북도                   0(0.00)  243,954,679,453(2.11)
# 14        제주도                   0(0.00)   16,992,346,795(0.15)
# 15        충남도                   0(0.00)  166,243,344,811(1.44)
# 16        충북도                   0(0.00)  341,956,877,278(2.96)
#
#                  tojiamt3          tojiarea1         tojiarea2  \
# 0                 0(0.00)   14,463,021(9.05)           0(0.00)
# 1                 0(0.00)  40,865,570(25.57)           0(0.00)
# 2                 0(0.00)    7,633,718(4.78)           0(0.00)
# 3                 0(0.00)   13,867,016(8.68)           0(0.00)
# 4                 0(0.00)    2,180,610(1.36)           0(0.00)
# ..                    ...                ...               ...
# 12  848,663,101,884(6.15)            0(0.00)   1,860,975(4.84)
# 13  292,344,133,966(2.12)            0(0.00)   2,450,196(6.37)
# 14  384,699,630,268(2.79)            0(0.00)     110,464(0.29)
# 15  404,933,802,330(2.93)            0(0.00)   2,512,985(6.53)
# 16  449,987,789,438(3.26)            0(0.00)  4,526,696(11.77)
#
#             tojiarea3                 etcamt1               etcamt2  \
# 0             0(0.00)    99,333,640,564(3.54)               0(0.00)
# 1             0(0.00)  948,868,534,810(33.82)               0(0.00)
# 2             0(0.00)   172,213,276,577(6.14)               0(0.00)
# 3             0(0.00)   110,851,155,768(3.95)               0(0.00)
# 4             0(0.00)    70,433,268,325(2.51)               0(0.00)
# ..                ...                     ...                   ...
# 12  16,556,862(23.22)                 0(0.00)  17,930,411,040(1.82)
# 13    5,127,293(7.19)                 0(0.00)  35,792,567,690(3.64)
# 14    1,693,428(2.37)                 0(0.00)     269,519,640(0.03)
# 15    3,947,778(5.54)                 0(0.00)  38,988,627,173(3.96)
# 16    5,311,890(7.45)                 0(0.00)  38,363,171,851(3.90)
#
#                   etcamt3               amtvariation        areavariation  \
# 0                 0(0.00)      451,227,581,370(0.00)     14,463,021(0.00)
# 1                 0(0.00)    9,202,335,466,881(0.00)     40,865,570(0.00)
# 2                 0(0.00)      604,141,703,714(0.00)      7,633,718(0.00)
# 3                 0(0.00)      574,172,774,664(0.00)     13,867,016(0.00)
# 4                 0(0.00)      269,266,244,769(0.00)      2,180,610(0.00)
# ..                    ...                        ...                  ...
# 12  127,666,815,933(7.91)   -52,720,195,100(-100.00)  -1,860,975(-100.00)
# 13   63,034,890,117(3.90)  -243,954,679,453(-100.00)  -2,450,196(-100.00)
# 14   19,996,035,681(1.24)   -16,992,346,795(-100.00)    -110,464(-100.00)
# 15   80,159,835,816(4.96)  -166,243,344,811(-100.00)  -2,512,985(-100.00)
# 16   68,963,974,525(4.27)  -341,956,877,278(-100.00)  -4,526,696(-100.00)
#
#                 etcvariation    totalarea1       totalamt1      totaletc1  \
# 0       99,333,640,564(0.00)  1.598489e+08  22369783497208  2805612523416
# 1      948,868,534,810(0.00)  1.598489e+08  22369783497208  2805612523416
# 2      172,213,276,577(0.00)  1.598489e+08  22369783497208  2805612523416
# 3      110,851,155,768(0.00)  1.598489e+08  22369783497208  2805612523416
# 4       70,433,268,325(0.00)  1.598489e+08  22369783497208  2805612523416
# ..                       ...           ...             ...            ...
# 12  -17,930,411,040(-100.00)  0.000000e+00               0              0
# 13  -35,792,567,690(-100.00)  0.000000e+00               0              0
# 14     -269,519,640(-100.00)  0.000000e+00               0              0
# 15  -38,988,627,173(-100.00)  0.000000e+00               0              0
# 16  -38,363,171,851(-100.00)  0.000000e+00               0              0
#
#       totalarea2       totalamt2     totaletc2    totalarea3       totalamt3  \
# 0   0.000000e+00               0             0  0.000000e+00               0
# 1   0.000000e+00               0             0  0.000000e+00               0
# 2   0.000000e+00               0             0  0.000000e+00               0
# 3   0.000000e+00               0             0  0.000000e+00               0
# 4   0.000000e+00               0             0  0.000000e+00               0
# ..           ...             ...           ...           ...             ...
# 12  3.847000e+07  11559740849440  983982565090  7.130932e+07  13810491556527
# 13  3.847000e+07  11559740849440  983982565090  7.130932e+07  13810491556527
# 14  3.847000e+07  11559740849440  983982565090  7.130932e+07  13810491556527
# 15  3.847000e+07  11559740849440  983982565090  7.130932e+07  13810491556527
# 16  3.847000e+07  11559740849440  983982565090  7.130932e+07  13810491556527
#
#         totaletc3
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 12  1614892298997
# 13  1614892298997
# 14  1614892298997
# 15  1614892298997
# 16  1614892298997
#
# [267 rows x 22 columns]

# %%
cf.savedata(resultDfMerged, SITENAME,DATANAME,SERVICENAME)
# Out:
# 공공용지 취득실적-시도별 면적 및 보상액 기준 실적 현황 save compled

# %%
resultDfMerged.shape
# Out:
# (267, 22)
